# %%
import requests
from bs4 import BeautifulSoup
import re
import os
import time
from urllib.parse import urljoin

# Set up base parameters
base_url = "https://archives.bulbagarden.net"
start_url = "https://archives.bulbagarden.net/wiki/Category:HOME_menu_sprites"
output_dir = "sprites"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36"
}

# Create output directory if it doesn't exist
os.makedirs(output_dir, exist_ok=True)

def get_soup(url, retries=3, delay=2):
    """Fetches a page and returns its BeautifulSoup object."""
    for attempt in range(retries):
        try:
            response = requests.get(url, headers=headers, timeout=10)
            response.raise_for_status()
            return BeautifulSoup(response.text, "html.parser")
        except requests.exceptions.RequestException as e:
            print(f"Error fetching {url} (attempt {attempt+1}/{retries}): {e}")
            time.sleep(delay)
    raise Exception(f"Failed to fetch {url} after {retries} attempts.")

def parse_images(soup):
    """Parses the image file names and returns their download URLs and target names."""
    file_links = soup.select("div.mw-category-generated li a")
    results = []

    for link in file_links:
        href = link.get("href")
        text = link.get_text()

        text_clean = text.replace(" ", "_")

        match = re.search(r"Menu_HOME_(\d{4}(?:-[\w]+)?)\.png", text_clean)
        if match:
            dex_id = match.group(1)
            filename = f"Sprite_{dex_id}.png"
            full_image_page = urljoin(base_url, href)
            results.append((full_image_page, filename))

    return results

def get_direct_image_url(image_page_url):
    """Gets the direct URL to the image file."""
    soup = get_soup(image_page_url)
    full_image = soup.select_one("div.fullImageLink a")
    if full_image:
        return urljoin(base_url, full_image.get("href"))
    return None

def download_image(img_url, dest_path):
    """Downloads an image if it doesn't already exist."""
    if not os.path.exists(dest_path):
        try:
            response = requests.get(img_url, headers=headers, timeout=10)
            response.raise_for_status()
            with open(dest_path, 'wb') as f:
                f.write(response.content)
            print(f"Downloaded: {dest_path}")
            time.sleep(1)  # be polite
        except Exception as e:
            print(f"Failed to download {img_url}: {e}")
    else:
        print(f"Already exists: {dest_path}")

def find_next_page(soup):
    """Finds the URL for the next page if it exists."""
    for link in soup.select("a"):
        if link.get_text(strip=True).lower() == "next page":
            return urljoin(base_url, link.get("href"))
    return None

def scrape_all(max_pages=10):
    current_url = start_url
    pages_scraped = 0
    while current_url and pages_scraped < max_pages:
        print(f"\nProcessing page: {current_url}")
        soup = get_soup(current_url)
        image_entries = parse_images(soup)
        for image_page_url, filename in image_entries:
            img_url = get_direct_image_url(image_page_url)
            if img_url:
                download_image(img_url, os.path.join(output_dir, filename))
        current_url = find_next_page(soup)
        pages_scraped += 1

if __name__ == "__main__":
    scrape_all()
# Out:
# Processing page: https://archives.bulbagarden.net/wiki/Category:HOME_menu_sprites
# Downloaded: sprites\Sprite_0001.png
# Downloaded: sprites\Sprite_0002.png
# Downloaded: sprites\Sprite_0003-Mega.png
# Downloaded: sprites\Sprite_0003.png
# Downloaded: sprites\Sprite_0004.png
# Downloaded: sprites\Sprite_0005.png
# Downloaded: sprites\Sprite_0006-Mega_X.png
# Downloaded: sprites\Sprite_0006-Mega_Y.png
# Downloaded: sprites\Sprite_0006.png
# Downloaded: sprites\Sprite_0007.png
# Downloaded: sprites\Sprite_0008.png
# Downloaded: sprites\Sprite_0009-Mega.png
# Downloaded: sprites\Sprite_0009.png
# Downloaded: sprites\Sprite_0010.png
# Downloaded: sprites\Sprite_0011.png
# Downloaded: sprites\Sprite_0012.png
# Downloaded: sprites\Sprite_0013.png
# Downloaded: sprites\Sprite_0014.png
# Downloaded: sprites\Sprite_0015-Mega.png
# Downloaded: sprites\Sprite_0015.png
# Downloaded: sprites\Sprite_0016.png
# Downloaded: sprites\Sprite_0017.png
# Downloaded: sprites\Sprite_0018-Mega.png
# Downloaded: sprites\Sprite_0018.png
# Downloaded: sprites\Sprite_0019-Alola.png
# Downloaded: sprites\Sprite_0019.png
# Downloaded: sprites\Sprite_0020-Alola.png
# Downloaded: sprites\Sprite_0020.png
# Downloaded: sprites\Sprite_0021.png
# Downloaded: sprites\Sprite_0022.png
# Downloaded: sprites\Sprite_0023.png
# Downloaded: sprites\Sprite_0024.png
# Downloaded: sprites\Sprite_0025-Alola.png
# Downloaded: sprites\Sprite_0025-Hoenn.png
# Downloaded: sprites\Sprite_0025-Kalos.png
# Downloaded: sprites\Sprite_0025-Original.png
# Downloaded: sprites\Sprite_0025-Partner.png
# Downloaded: sprites\Sprite_0025-Sinnoh.png
# Downloaded: sprites\Sprite_0025-Unova.png
# Downloaded: sprites\Sprite_0025-World.png
# Downloaded: sprites\Sprite_0025.png
# Downloaded: sprites\Sprite_0026-Alola.png
# Downloaded: sprites\Sprite_0026.png
# Downloaded: sprites\Sprite_0027-Alola.png
# Downloaded: sprites\Sprite_0027.png
# Downloaded: sprites\Sprite_0028-Alola.png
# Downloaded: sprites\Sprite_0028.png
# Downloaded: sprites\Sprite_0029.png
# Downloaded: sprites\Sprite_0030.png
# Downloaded: sprites\Sprite_0031.png
# Downloaded: sprites\Sprite_0032.png
# Downloaded: sprites\Sprite_0033.png
# Downloaded: sprites\Sprite_0034.png
# Downloaded: sprites\Sprite_0035.png
# Downloaded: sprites\Sprite_0036.png
# Downloaded: sprites\Sprite_0037-Alola.png
# Downloaded: sprites\Sprite_0037.png
# Downloaded: sprites\Sprite_0038-Alola.png
# Downloaded: sprites\Sprite_0038.png
# Downloaded: sprites\Sprite_0039.png
# Downloaded: sprites\Sprite_0040.png
# Downloaded: sprites\Sprite_0041.png
# Downloaded: sprites\Sprite_0042.png
# Downloaded: sprites\Sprite_0043.png
# Downloaded: sprites\Sprite_0044.png
# Downloaded: sprites\Sprite_0045.png
# Downloaded: sprites\Sprite_0046.png
# Downloaded: sprites\Sprite_0047.png
# Downloaded: sprites\Sprite_0048.png
# Downloaded: sprites\Sprite_0049.png
# Downloaded: sprites\Sprite_0050-Alola.png
# Downloaded: sprites\Sprite_0050.png
# Downloaded: sprites\Sprite_0051-Alola.png
# Downloaded: sprites\Sprite_0051.png
# Downloaded: sprites\Sprite_0052-Alola.png
# Downloaded: sprites\Sprite_0052-Galar.png
# Downloaded: sprites\Sprite_0052.png
# Downloaded: sprites\Sprite_0053-Alola.png
# Downloaded: sprites\Sprite_0053.png
# Downloaded: sprites\Sprite_0054.png
# Downloaded: sprites\Sprite_0055.png
# Downloaded: sprites\Sprite_0056.png
# Downloaded: sprites\Sprite_0057.png
# Downloaded: sprites\Sprite_0058-Hisui.png
# Downloaded: sprites\Sprite_0058.png
# Downloaded: sprites\Sprite_0059-Hisui.png
# Downloaded: sprites\Sprite_0059.png
# Downloaded: sprites\Sprite_0060.png
# Downloaded: sprites\Sprite_0061.png
# Downloaded: sprites\Sprite_0062.png
# Downloaded: sprites\Sprite_0063.png
# Downloaded: sprites\Sprite_0064.png
# Downloaded: sprites\Sprite_0065-Mega.png
# Downloaded: sprites\Sprite_0065.png
# Downloaded: sprites\Sprite_0066.png
# Downloaded: sprites\Sprite_0067.png
# Downloaded: sprites\Sprite_0068.png
# Downloaded: sprites\Sprite_0069.png
# Downloaded: sprites\Sprite_0070.png
# Downloaded: sprites\Sprite_0071.png
# Downloaded: sprites\Sprite_0072.png
# Downloaded: sprites\Sprite_0073.png
# Downloaded: sprites\Sprite_0074-Alola.png
# Downloaded: sprites\Sprite_0074.png
# Downloaded: sprites\Sprite_0075-Alola.png
# Downloaded: sprites\Sprite_0075.png
# Downloaded: sprites\Sprite_0076-Alola.png
# Downloaded: sprites\Sprite_0076.png
# Downloaded: sprites\Sprite_0077-Galar.png
# Downloaded: sprites\Sprite_0077.png
# Downloaded: sprites\Sprite_0078-Galar.png
# Downloaded: sprites\Sprite_0078.png
# Downloaded: sprites\Sprite_0079-Galar.png
# Downloaded: sprites\Sprite_0079.png
# Downloaded: sprites\Sprite_0080-Galar.png
# Downloaded: sprites\Sprite_0080-Mega.png
# Downloaded: sprites\Sprite_0080.png
# Downloaded: sprites\Sprite_0081.png
# Downloaded: sprites\Sprite_0082.png
# Downloaded: sprites\Sprite_0083-Galar.png
# Downloaded: sprites\Sprite_0083.png
# Downloaded: sprites\Sprite_0084.png
# Downloaded: sprites\Sprite_0085.png
# Downloaded: sprites\Sprite_0086.png
# Downloaded: sprites\Sprite_0087.png
# Downloaded: sprites\Sprite_0088-Alola.png
# Downloaded: sprites\Sprite_0088.png
# Downloaded: sprites\Sprite_0089-Alola.png
# Downloaded: sprites\Sprite_0089.png
# Downloaded: sprites\Sprite_0090.png
# Downloaded: sprites\Sprite_0091.png
# Downloaded: sprites\Sprite_0092.png
# Downloaded: sprites\Sprite_0093.png
# Downloaded: sprites\Sprite_0094-Mega.png
# Downloaded: sprites\Sprite_0094.png
# Downloaded: sprites\Sprite_0095.png
# Downloaded: sprites\Sprite_0096.png
# Downloaded: sprites\Sprite_0097.png
# Downloaded: sprites\Sprite_0098.png
# Downloaded: sprites\Sprite_0099.png
# Downloaded: sprites\Sprite_0100-Hisui.png
# Downloaded: sprites\Sprite_0100.png
# Downloaded: sprites\Sprite_0101-Hisui.png
# Downloaded: sprites\Sprite_0101.png
# Downloaded: sprites\Sprite_0102.png
# Downloaded: sprites\Sprite_0103-Alola.png
# Downloaded: sprites\Sprite_0103.png
# Downloaded: sprites\Sprite_0104.png
# Downloaded: sprites\Sprite_0105-Alola.png
# Downloaded: sprites\Sprite_0105.png
# Downloaded: sprites\Sprite_0106.png
# Downloaded: sprites\Sprite_0107.png
# Downloaded: sprites\Sprite_0108.png
# Downloaded: sprites\Sprite_0109.png
# Downloaded: sprites\Sprite_0110-Galar.png
# Downloaded: sprites\Sprite_0110.png
# Downloaded: sprites\Sprite_0111.png
# Downloaded: sprites\Sprite_0112.png
# Downloaded: sprites\Sprite_0113.png
# Downloaded: sprites\Sprite_0114.png
# Downloaded: sprites\Sprite_0115-Mega.png
# Downloaded: sprites\Sprite_0115.png
# Downloaded: sprites\Sprite_0116.png
# Downloaded: sprites\Sprite_0117.png
# Downloaded: sprites\Sprite_0118.png
# Downloaded: sprites\Sprite_0119.png
# Downloaded: sprites\Sprite_0120.png
# Downloaded: sprites\Sprite_0121.png
# Downloaded: sprites\Sprite_0122-Galar.png
# Downloaded: sprites\Sprite_0122.png
# Downloaded: sprites\Sprite_0123.png
# Downloaded: sprites\Sprite_0124.png
# Downloaded: sprites\Sprite_0125.png
# Downloaded: sprites\Sprite_0126.png
# Downloaded: sprites\Sprite_0127-Mega.png
# Downloaded: sprites\Sprite_0127.png
# Downloaded: sprites\Sprite_0128-Paldea_Aqua.png
# Downloaded: sprites\Sprite_0128-Paldea_Blaze.png
# Downloaded: sprites\Sprite_0128-Paldea_Combat.png
# Downloaded: sprites\Sprite_0128.png
# Downloaded: sprites\Sprite_0129.png
# Downloaded: sprites\Sprite_0130-Mega.png
# Downloaded: sprites\Sprite_0130.png
# Downloaded: sprites\Sprite_0131.png
# Downloaded: sprites\Sprite_0132.png
# Downloaded: sprites\Sprite_0133.png
# Downloaded: sprites\Sprite_0134.png
# Downloaded: sprites\Sprite_0135.png
# Downloaded: sprites\Sprite_0136.png
# Downloaded: sprites\Sprite_0137.png
# Downloaded: sprites\Sprite_0138.png
# Downloaded: sprites\Sprite_0139.png
# Downloaded: sprites\Sprite_0140.png
# Downloaded: sprites\Sprite_0141.png
# Downloaded: sprites\Sprite_0142-Mega.png
# Downloaded: sprites\Sprite_0142.png
# Downloaded: sprites\Sprite_0143.png
# Downloaded: sprites\Sprite_0144-Galar.png
# Downloaded: sprites\Sprite_0144.png
# Downloaded: sprites\Sprite_0145-Galar.png
#
# Processing page: https://archives.bulbagarden.net/w/index.php?title=Category:HOME_menu_sprites&filefrom=Menu+HOME+0145.png#mw-category-media
# Downloaded: sprites\Sprite_0145.png
# Downloaded: sprites\Sprite_0146-Galar.png
# Downloaded: sprites\Sprite_0146.png
# Downloaded: sprites\Sprite_0147.png
# Downloaded: sprites\Sprite_0148.png
# Downloaded: sprites\Sprite_0149.png
# Downloaded: sprites\Sprite_0150-Mega_X.png
# Downloaded: sprites\Sprite_0150-Mega_Y.png
# Downloaded: sprites\Sprite_0150.png
# Downloaded: sprites\Sprite_0151.png
# Downloaded: sprites\Sprite_0152.png
# Downloaded: sprites\Sprite_0153.png
# Downloaded: sprites\Sprite_0154.png
# Downloaded: sprites\Sprite_0155.png
# Downloaded: sprites\Sprite_0156.png
# Downloaded: sprites\Sprite_0157-Hisui.png
# Downloaded: sprites\Sprite_0157.png
# Downloaded: sprites\Sprite_0158.png
# Downloaded: sprites\Sprite_0159.png
# Downloaded: sprites\Sprite_0160.png
# Downloaded: sprites\Sprite_0161.png
# Downloaded: sprites\Sprite_0162.png
# Downloaded: sprites\Sprite_0163.png
# Downloaded: sprites\Sprite_0164.png
# Downloaded: sprites\Sprite_0165.png
# Downloaded: sprites\Sprite_0166.png
# Downloaded: sprites\Sprite_0167.png
# Downloaded: sprites\Sprite_0168.png
# Downloaded: sprites\Sprite_0169.png
# Downloaded: sprites\Sprite_0170.png
# Downloaded: sprites\Sprite_0171.png
# Downloaded: sprites\Sprite_0172.png
# Downloaded: sprites\Sprite_0173.png
# Downloaded: sprites\Sprite_0174.png
# Downloaded: sprites\Sprite_0175.png
# Downloaded: sprites\Sprite_0176.png
# Downloaded: sprites\Sprite_0177.png
# Downloaded: sprites\Sprite_0178.png
# Downloaded: sprites\Sprite_0179.png
# Downloaded: sprites\Sprite_0180.png
# Downloaded: sprites\Sprite_0181-Mega.png
# Downloaded: sprites\Sprite_0181.png
# Downloaded: sprites\Sprite_0182.png
# Downloaded: sprites\Sprite_0183.png
# Downloaded: sprites\Sprite_0184.png
# Downloaded: sprites\Sprite_0185.png
# Downloaded: sprites\Sprite_0186.png
# Downloaded: sprites\Sprite_0187.png
# Downloaded: sprites\Sprite_0188.png
# Downloaded: sprites\Sprite_0189.png
# Downloaded: sprites\Sprite_0190.png
# Downloaded: sprites\Sprite_0191.png
# Downloaded: sprites\Sprite_0192.png
# Downloaded: sprites\Sprite_0193.png
# Downloaded: sprites\Sprite_0194-Paldea.png
# Downloaded: sprites\Sprite_0194.png
# Downloaded: sprites\Sprite_0195.png
# Downloaded: sprites\Sprite_0196.png
# Downloaded: sprites\Sprite_0197.png
# Downloaded: sprites\Sprite_0198.png
# Downloaded: sprites\Sprite_0199-Galar.png
# Downloaded: sprites\Sprite_0199.png
# Downloaded: sprites\Sprite_0200.png
# Downloaded: sprites\Sprite_0201-B.png
# Downloaded: sprites\Sprite_0201-C.png
# Downloaded: sprites\Sprite_0201-D.png
# Downloaded: sprites\Sprite_0201-E.png
# Downloaded: sprites\Sprite_0201-Exclamation.png
# Downloaded: sprites\Sprite_0201-F.png
# Downloaded: sprites\Sprite_0201-G.png
# Downloaded: sprites\Sprite_0201-H.png
# Downloaded: sprites\Sprite_0201-I.png
# Downloaded: sprites\Sprite_0201-J.png
# Downloaded: sprites\Sprite_0201-K.png
# Downloaded: sprites\Sprite_0201-L.png
# Downloaded: sprites\Sprite_0201-M.png
# Downloaded: sprites\Sprite_0201-N.png
# Downloaded: sprites\Sprite_0201-O.png
# Downloaded: sprites\Sprite_0201-P.png
# Downloaded: sprites\Sprite_0201-Q.png
# Downloaded: sprites\Sprite_0201-Question.png
# Downloaded: sprites\Sprite_0201-R.png
# Downloaded: sprites\Sprite_0201-S.png
# Downloaded: sprites\Sprite_0201-T.png
# Downloaded: sprites\Sprite_0201-U.png
# Downloaded: sprites\Sprite_0201-V.png
# Downloaded: sprites\Sprite_0201-W.png
# Downloaded: sprites\Sprite_0201-X.png
# Downloaded: sprites\Sprite_0201-Y.png
# Downloaded: sprites\Sprite_0201-Z.png
# Downloaded: sprites\Sprite_0201.png
# Downloaded: sprites\Sprite_0202.png
# Downloaded: sprites\Sprite_0203.png
# Downloaded: sprites\Sprite_0204.png
# Downloaded: sprites\Sprite_0205.png
# Downloaded: sprites\Sprite_0206.png
# Downloaded: sprites\Sprite_0207.png
# Downloaded: sprites\Sprite_0208-Mega.png
# Downloaded: sprites\Sprite_0208.png
# Downloaded: sprites\Sprite_0209.png
# Downloaded: sprites\Sprite_0210.png
# Downloaded: sprites\Sprite_0211-Hisui.png
# Downloaded: sprites\Sprite_0211.png
# Downloaded: sprites\Sprite_0212-Mega.png
# Downloaded: sprites\Sprite_0212.png
# Downloaded: sprites\Sprite_0213.png
# Downloaded: sprites\Sprite_0214-Mega.png
# Downloaded: sprites\Sprite_0214.png
# Downloaded: sprites\Sprite_0215-Hisui.png
# Downloaded: sprites\Sprite_0215.png
# Downloaded: sprites\Sprite_0216.png
# Downloaded: sprites\Sprite_0217.png
# Downloaded: sprites\Sprite_0218.png
# Downloaded: sprites\Sprite_0219.png
# Downloaded: sprites\Sprite_0220.png
# Downloaded: sprites\Sprite_0221.png
# Downloaded: sprites\Sprite_0222-Galar.png
# Downloaded: sprites\Sprite_0222.png
# Downloaded: sprites\Sprite_0223.png
# Downloaded: sprites\Sprite_0224.png
# Downloaded: sprites\Sprite_0225.png
# Downloaded: sprites\Sprite_0226.png
# Downloaded: sprites\Sprite_0227.png
# Downloaded: sprites\Sprite_0228.png
# Downloaded: sprites\Sprite_0229-Mega.png
# Downloaded: sprites\Sprite_0229.png
# Downloaded: sprites\Sprite_0230.png
# Downloaded: sprites\Sprite_0231.png
# Downloaded: sprites\Sprite_0232.png
# Downloaded: sprites\Sprite_0233.png
# Downloaded: sprites\Sprite_0234.png
# Downloaded: sprites\Sprite_0235.png
# Downloaded: sprites\Sprite_0236.png
# Downloaded: sprites\Sprite_0237.png
# Downloaded: sprites\Sprite_0238.png
# Downloaded: sprites\Sprite_0239.png
# Downloaded: sprites\Sprite_0240.png
# Downloaded: sprites\Sprite_0241.png
# Downloaded: sprites\Sprite_0242.png
# Downloaded: sprites\Sprite_0243.png
# Downloaded: sprites\Sprite_0244.png
# Downloaded: sprites\Sprite_0245.png
# Downloaded: sprites\Sprite_0246.png
# Downloaded: sprites\Sprite_0247.png
# Downloaded: sprites\Sprite_0248-Mega.png
# Downloaded: sprites\Sprite_0248.png
# Downloaded: sprites\Sprite_0249.png
# Downloaded: sprites\Sprite_0250.png
# Downloaded: sprites\Sprite_0251.png
# Downloaded: sprites\Sprite_0252.png
# Downloaded: sprites\Sprite_0253.png
# Downloaded: sprites\Sprite_0254-Mega.png
# Downloaded: sprites\Sprite_0254.png
# Downloaded: sprites\Sprite_0255.png
# Downloaded: sprites\Sprite_0256.png
# Downloaded: sprites\Sprite_0257-Mega.png
# Downloaded: sprites\Sprite_0257.png
# Downloaded: sprites\Sprite_0258.png
# Downloaded: sprites\Sprite_0259.png
# Downloaded: sprites\Sprite_0260-Mega.png
# Downloaded: sprites\Sprite_0260.png
# Downloaded: sprites\Sprite_0261.png
# Downloaded: sprites\Sprite_0262.png
# Downloaded: sprites\Sprite_0263-Galar.png
# Downloaded: sprites\Sprite_0263.png
# Downloaded: sprites\Sprite_0264-Galar.png
# Downloaded: sprites\Sprite_0264.png
# Downloaded: sprites\Sprite_0265.png
# Downloaded: sprites\Sprite_0266.png
# Downloaded: sprites\Sprite_0267.png
# Downloaded: sprites\Sprite_0268.png
# Downloaded: sprites\Sprite_0269.png
# Downloaded: sprites\Sprite_0270.png
# Downloaded: sprites\Sprite_0271.png
# Downloaded: sprites\Sprite_0272.png
# Downloaded: sprites\Sprite_0273.png
# Downloaded: sprites\Sprite_0274.png
# Downloaded: sprites\Sprite_0275.png
# Downloaded: sprites\Sprite_0276.png
# Downloaded: sprites\Sprite_0277.png
# Downloaded: sprites\Sprite_0278.png
# Downloaded: sprites\Sprite_0279.png
# Downloaded: sprites\Sprite_0280.png
# Downloaded: sprites\Sprite_0281.png
# Downloaded: sprites\Sprite_0282-Mega.png
# Downloaded: sprites\Sprite_0282.png
# Downloaded: sprites\Sprite_0283.png
# Downloaded: sprites\Sprite_0284.png
# Downloaded: sprites\Sprite_0285.png
# Downloaded: sprites\Sprite_0286.png
# Downloaded: sprites\Sprite_0287.png
# Downloaded: sprites\Sprite_0288.png
# Downloaded: sprites\Sprite_0289.png
# Downloaded: sprites\Sprite_0290.png
# Downloaded: sprites\Sprite_0291.png
# Downloaded: sprites\Sprite_0292.png
# Downloaded: sprites\Sprite_0293.png
# Downloaded: sprites\Sprite_0294.png
# Downloaded: sprites\Sprite_0295.png
# Downloaded: sprites\Sprite_0296.png
#
# Processing page: https://archives.bulbagarden.net/w/index.php?title=Category:HOME_menu_sprites&filefrom=Menu+HOME+0297.png#mw-category-media
# Downloaded: sprites\Sprite_0297.png
# Downloaded: sprites\Sprite_0298.png
# Downloaded: sprites\Sprite_0299.png
# Downloaded: sprites\Sprite_0300.png
# Downloaded: sprites\Sprite_0301.png
# Downloaded: sprites\Sprite_0302-Mega.png
# Downloaded: sprites\Sprite_0302.png
# Downloaded: sprites\Sprite_0303-Mega.png
# Downloaded: sprites\Sprite_0303.png
# Downloaded: sprites\Sprite_0304.png
# Downloaded: sprites\Sprite_0305.png
# Downloaded: sprites\Sprite_0306-Mega.png
# Downloaded: sprites\Sprite_0306.png
# Downloaded: sprites\Sprite_0307.png
# Downloaded: sprites\Sprite_0308-Mega.png
# Downloaded: sprites\Sprite_0308.png
# Downloaded: sprites\Sprite_0309.png
# Downloaded: sprites\Sprite_0310-Mega.png
# Downloaded: sprites\Sprite_0310.png
# Downloaded: sprites\Sprite_0311.png
# Downloaded: sprites\Sprite_0312.png
# Downloaded: sprites\Sprite_0313.png
# Downloaded: sprites\Sprite_0314.png
# Downloaded: sprites\Sprite_0315.png
# Downloaded: sprites\Sprite_0316.png
# Downloaded: sprites\Sprite_0317.png
# Downloaded: sprites\Sprite_0318.png
# Downloaded: sprites\Sprite_0319-Mega.png
# Downloaded: sprites\Sprite_0319.png
# Downloaded: sprites\Sprite_0320.png
# Downloaded: sprites\Sprite_0321.png
# Downloaded: sprites\Sprite_0322.png
# Downloaded: sprites\Sprite_0323-Mega.png
# Downloaded: sprites\Sprite_0323.png
# Downloaded: sprites\Sprite_0324.png
# Downloaded: sprites\Sprite_0325.png
# Downloaded: sprites\Sprite_0326.png
# Downloaded: sprites\Sprite_0327.png
# Downloaded: sprites\Sprite_0328.png
# Downloaded: sprites\Sprite_0329.png
# Downloaded: sprites\Sprite_0330.png
# Downloaded: sprites\Sprite_0331.png
# Downloaded: sprites\Sprite_0332.png
# Downloaded: sprites\Sprite_0333.png
# Downloaded: sprites\Sprite_0334-Mega.png
# Downloaded: sprites\Sprite_0334.png
# Downloaded: sprites\Sprite_0335.png
# Downloaded: sprites\Sprite_0336.png
# Downloaded: sprites\Sprite_0337.png
# Downloaded: sprites\Sprite_0338.png
# Downloaded: sprites\Sprite_0339.png
# Downloaded: sprites\Sprite_0340.png
# Downloaded: sprites\Sprite_0341.png
# Downloaded: sprites\Sprite_0342.png
# Downloaded: sprites\Sprite_0343.png
# Downloaded: sprites\Sprite_0344.png
# Downloaded: sprites\Sprite_0345.png
# Downloaded: sprites\Sprite_0346.png
# Downloaded: sprites\Sprite_0347.png
# Downloaded: sprites\Sprite_0348.png
# Downloaded: sprites\Sprite_0349.png
# Downloaded: sprites\Sprite_0350.png
# Downloaded: sprites\Sprite_0351-Rainy.png
# Downloaded: sprites\Sprite_0351-Snowy.png
# Downloaded: sprites\Sprite_0351-Sunny.png
# Downloaded: sprites\Sprite_0351.png
# Downloaded: sprites\Sprite_0352.png
# Downloaded: sprites\Sprite_0353.png
# Downloaded: sprites\Sprite_0354-Mega.png
# Downloaded: sprites\Sprite_0354.png
# Downloaded: sprites\Sprite_0355.png
# Downloaded: sprites\Sprite_0356.png
# Downloaded: sprites\Sprite_0357.png
# Downloaded: sprites\Sprite_0358.png
# Downloaded: sprites\Sprite_0359-Mega.png
# Downloaded: sprites\Sprite_0359.png
# Downloaded: sprites\Sprite_0360.png
# Downloaded: sprites\Sprite_0361.png
# Downloaded: sprites\Sprite_0362-Mega.png
# Downloaded: sprites\Sprite_0362.png
# Downloaded: sprites\Sprite_0363.png
# Downloaded: sprites\Sprite_0364.png
# Downloaded: sprites\Sprite_0365.png
# Downloaded: sprites\Sprite_0366.png
# Downloaded: sprites\Sprite_0367.png
# Downloaded: sprites\Sprite_0368.png
# Downloaded: sprites\Sprite_0369.png
# Downloaded: sprites\Sprite_0370.png
# Downloaded: sprites\Sprite_0371.png
# Downloaded: sprites\Sprite_0372.png
# Downloaded: sprites\Sprite_0373-Mega.png
# Downloaded: sprites\Sprite_0373.png
# Downloaded: sprites\Sprite_0374.png
# Downloaded: sprites\Sprite_0375.png
# Downloaded: sprites\Sprite_0376-Mega.png
# Downloaded: sprites\Sprite_0376.png
# Downloaded: sprites\Sprite_0377.png
# Downloaded: sprites\Sprite_0378.png
# Downloaded: sprites\Sprite_0379.png
# Downloaded: sprites\Sprite_0380-Mega.png
# Downloaded: sprites\Sprite_0380.png
# Downloaded: sprites\Sprite_0381-Mega.png
# Downloaded: sprites\Sprite_0381.png
# Downloaded: sprites\Sprite_0382-Primal.png
# Downloaded: sprites\Sprite_0382.png
# Downloaded: sprites\Sprite_0383-Primal.png
# Downloaded: sprites\Sprite_0383.png
# Downloaded: sprites\Sprite_0384-Mega.png
# Downloaded: sprites\Sprite_0384.png
# Downloaded: sprites\Sprite_0385.png
# Downloaded: sprites\Sprite_0386-Attack.png
# Downloaded: sprites\Sprite_0386-Defense.png
# Downloaded: sprites\Sprite_0386-Speed.png
# Downloaded: sprites\Sprite_0386.png
# Downloaded: sprites\Sprite_0387.png
# Downloaded: sprites\Sprite_0388.png
# Downloaded: sprites\Sprite_0389.png
# Downloaded: sprites\Sprite_0390.png
# Downloaded: sprites\Sprite_0391.png
# Downloaded: sprites\Sprite_0392.png
# Downloaded: sprites\Sprite_0393.png
# Downloaded: sprites\Sprite_0394.png
# Downloaded: sprites\Sprite_0395.png
# Downloaded: sprites\Sprite_0396.png
# Downloaded: sprites\Sprite_0397.png
# Downloaded: sprites\Sprite_0398.png
# Downloaded: sprites\Sprite_0399.png
# Downloaded: sprites\Sprite_0400.png
# Downloaded: sprites\Sprite_0401.png
# Downloaded: sprites\Sprite_0402.png
# Downloaded: sprites\Sprite_0403.png
# Downloaded: sprites\Sprite_0404.png
# Downloaded: sprites\Sprite_0405.png
# Downloaded: sprites\Sprite_0406.png
# Downloaded: sprites\Sprite_0407.png
# Downloaded: sprites\Sprite_0408.png
# Downloaded: sprites\Sprite_0409.png
# Downloaded: sprites\Sprite_0410.png
# Downloaded: sprites\Sprite_0411.png
# Downloaded: sprites\Sprite_0412-Sandy.png
# Downloaded: sprites\Sprite_0412-Trash.png
# Downloaded: sprites\Sprite_0412.png
# Downloaded: sprites\Sprite_0413-Sandy.png
# Downloaded: sprites\Sprite_0413-Trash.png
# Downloaded: sprites\Sprite_0413.png
# Downloaded: sprites\Sprite_0414.png
# Downloaded: sprites\Sprite_0415.png
# Downloaded: sprites\Sprite_0416.png
# Downloaded: sprites\Sprite_0417.png
# Downloaded: sprites\Sprite_0418.png
# Downloaded: sprites\Sprite_0419.png
# Downloaded: sprites\Sprite_0420.png
# Downloaded: sprites\Sprite_0421-Sunshine.png
# Downloaded: sprites\Sprite_0421.png
# Downloaded: sprites\Sprite_0422-East.png
# Downloaded: sprites\Sprite_0422.png
# Downloaded: sprites\Sprite_0423-East.png
# Downloaded: sprites\Sprite_0423.png
# Downloaded: sprites\Sprite_0424.png
# Downloaded: sprites\Sprite_0425.png
# Downloaded: sprites\Sprite_0426.png
# Downloaded: sprites\Sprite_0427.png
# Downloaded: sprites\Sprite_0428-Mega.png
# Downloaded: sprites\Sprite_0428.png
# Downloaded: sprites\Sprite_0429.png
# Downloaded: sprites\Sprite_0430.png
# Downloaded: sprites\Sprite_0431.png
# Downloaded: sprites\Sprite_0432.png
# Downloaded: sprites\Sprite_0433.png
# Downloaded: sprites\Sprite_0434.png
# Downloaded: sprites\Sprite_0435.png
# Downloaded: sprites\Sprite_0436.png
# Downloaded: sprites\Sprite_0437.png
# Downloaded: sprites\Sprite_0438.png
# Downloaded: sprites\Sprite_0439.png
# Downloaded: sprites\Sprite_0440.png
# Downloaded: sprites\Sprite_0441.png
# Downloaded: sprites\Sprite_0442.png
# Downloaded: sprites\Sprite_0443.png
# Downloaded: sprites\Sprite_0444.png
# Downloaded: sprites\Sprite_0445-Mega.png
# Downloaded: sprites\Sprite_0445.png
# Downloaded: sprites\Sprite_0446.png
# Downloaded: sprites\Sprite_0447.png
# Downloaded: sprites\Sprite_0448-Mega.png
# Downloaded: sprites\Sprite_0448.png
# Downloaded: sprites\Sprite_0449.png
# Downloaded: sprites\Sprite_0450.png
# Downloaded: sprites\Sprite_0451.png
# Downloaded: sprites\Sprite_0452.png
# Downloaded: sprites\Sprite_0453.png
# Downloaded: sprites\Sprite_0454.png
# Downloaded: sprites\Sprite_0455.png
# Downloaded: sprites\Sprite_0456.png
# Downloaded: sprites\Sprite_0457.png
# Downloaded: sprites\Sprite_0458.png
# Downloaded: sprites\Sprite_0459.png
# Downloaded: sprites\Sprite_0460-Mega.png
# Downloaded: sprites\Sprite_0460.png
# Downloaded: sprites\Sprite_0461.png
#
# Processing page: https://archives.bulbagarden.net/w/index.php?title=Category:HOME_menu_sprites&filefrom=Menu+HOME+0462.png#mw-category-media
# Downloaded: sprites\Sprite_0462.png
# Downloaded: sprites\Sprite_0463.png
# Downloaded: sprites\Sprite_0464.png
# Downloaded: sprites\Sprite_0465.png
# Downloaded: sprites\Sprite_0466.png
# Downloaded: sprites\Sprite_0467.png
# Downloaded: sprites\Sprite_0468.png
# Downloaded: sprites\Sprite_0469.png
# Downloaded: sprites\Sprite_0470.png
# Downloaded: sprites\Sprite_0471.png
# Downloaded: sprites\Sprite_0472.png
# Downloaded: sprites\Sprite_0473.png
# Downloaded: sprites\Sprite_0474.png
# Downloaded: sprites\Sprite_0475-Mega.png
# Downloaded: sprites\Sprite_0475.png
# Downloaded: sprites\Sprite_0476.png
# Downloaded: sprites\Sprite_0477.png
# Downloaded: sprites\Sprite_0478.png
# Downloaded: sprites\Sprite_0479-Fan.png
# Downloaded: sprites\Sprite_0479-Frost.png
# Downloaded: sprites\Sprite_0479-Heat.png
# Downloaded: sprites\Sprite_0479-Mow.png
# Downloaded: sprites\Sprite_0479-Wash.png
# Downloaded: sprites\Sprite_0479.png
# Downloaded: sprites\Sprite_0480.png
# Downloaded: sprites\Sprite_0481.png
# Downloaded: sprites\Sprite_0482.png
# Downloaded: sprites\Sprite_0483-Origin.png
# Downloaded: sprites\Sprite_0483.png
# Downloaded: sprites\Sprite_0484-Origin.png
# Downloaded: sprites\Sprite_0484.png
# Downloaded: sprites\Sprite_0485.png
# Downloaded: sprites\Sprite_0486.png
# Downloaded: sprites\Sprite_0487-Origin.png
# Downloaded: sprites\Sprite_0487.png
# Downloaded: sprites\Sprite_0488.png
# Downloaded: sprites\Sprite_0489.png
# Downloaded: sprites\Sprite_0490.png
# Downloaded: sprites\Sprite_0491.png
# Downloaded: sprites\Sprite_0492-Sky.png
# Downloaded: sprites\Sprite_0492.png
# Downloaded: sprites\Sprite_0493-Bug.png
# Downloaded: sprites\Sprite_0493-Dark.png
# Downloaded: sprites\Sprite_0493-Dragon.png
# Downloaded: sprites\Sprite_0493-Electric.png
# Downloaded: sprites\Sprite_0493-Fairy.png
# Downloaded: sprites\Sprite_0493-Fighting.png
# Downloaded: sprites\Sprite_0493-Fire.png
# Downloaded: sprites\Sprite_0493-Flying.png
# Downloaded: sprites\Sprite_0493-Ghost.png
# Downloaded: sprites\Sprite_0493-Grass.png
# Downloaded: sprites\Sprite_0493-Ground.png
# Downloaded: sprites\Sprite_0493-Ice.png
# Downloaded: sprites\Sprite_0493-Poison.png
# Downloaded: sprites\Sprite_0493-Psychic.png
# Downloaded: sprites\Sprite_0493-Rock.png
# Downloaded: sprites\Sprite_0493-Steel.png
# Downloaded: sprites\Sprite_0493-Water.png
# Downloaded: sprites\Sprite_0493.png
# Downloaded: sprites\Sprite_0494.png
# Downloaded: sprites\Sprite_0495.png
# Downloaded: sprites\Sprite_0496.png
# Downloaded: sprites\Sprite_0497.png
# Downloaded: sprites\Sprite_0498.png
# Downloaded: sprites\Sprite_0499.png
# Downloaded: sprites\Sprite_0500.png
# Downloaded: sprites\Sprite_0501.png
# Downloaded: sprites\Sprite_0502.png
# Downloaded: sprites\Sprite_0503-Hisui.png
# Downloaded: sprites\Sprite_0503.png
# Downloaded: sprites\Sprite_0504.png
# Downloaded: sprites\Sprite_0505.png
# Downloaded: sprites\Sprite_0506.png
# Downloaded: sprites\Sprite_0507.png
# Downloaded: sprites\Sprite_0508.png
# Downloaded: sprites\Sprite_0509.png
# Downloaded: sprites\Sprite_0510.png
# Downloaded: sprites\Sprite_0511.png
# Downloaded: sprites\Sprite_0512.png
# Downloaded: sprites\Sprite_0513.png
# Downloaded: sprites\Sprite_0514.png
# Downloaded: sprites\Sprite_0515.png
# Downloaded: sprites\Sprite_0516.png
# Downloaded: sprites\Sprite_0517.png
# Downloaded: sprites\Sprite_0518.png
# Downloaded: sprites\Sprite_0519.png
# Downloaded: sprites\Sprite_0520.png
# Downloaded: sprites\Sprite_0521-Female.png
# Downloaded: sprites\Sprite_0521.png
# Downloaded: sprites\Sprite_0522.png
# Downloaded: sprites\Sprite_0523.png
# Downloaded: sprites\Sprite_0524.png
# Downloaded: sprites\Sprite_0525.png
# Downloaded: sprites\Sprite_0526.png
# Downloaded: sprites\Sprite_0527.png
# Downloaded: sprites\Sprite_0528.png
# Downloaded: sprites\Sprite_0529.png
# Downloaded: sprites\Sprite_0530.png
# Downloaded: sprites\Sprite_0531-Mega.png
# Downloaded: sprites\Sprite_0531.png
# Downloaded: sprites\Sprite_0532.png
# Downloaded: sprites\Sprite_0533.png
# Downloaded: sprites\Sprite_0534.png
# Downloaded: sprites\Sprite_0535.png
# Downloaded: sprites\Sprite_0536.png
# Downloaded: sprites\Sprite_0537.png
# Downloaded: sprites\Sprite_0538.png
# Downloaded: sprites\Sprite_0539.png
# Downloaded: sprites\Sprite_0540.png
# Downloaded: sprites\Sprite_0541.png
# Downloaded: sprites\Sprite_0542.png
# Downloaded: sprites\Sprite_0543.png
# Downloaded: sprites\Sprite_0544.png
# Downloaded: sprites\Sprite_0545.png
# Downloaded: sprites\Sprite_0546.png
# Downloaded: sprites\Sprite_0547.png
# Downloaded: sprites\Sprite_0548.png
# Downloaded: sprites\Sprite_0549-Hisui.png
# Downloaded: sprites\Sprite_0549.png
# Downloaded: sprites\Sprite_0550-Blue.png
# Downloaded: sprites\Sprite_0550-White.png
# Downloaded: sprites\Sprite_0550.png
# Downloaded: sprites\Sprite_0551.png
# Downloaded: sprites\Sprite_0552.png
# Downloaded: sprites\Sprite_0553.png
# Downloaded: sprites\Sprite_0554-Galar.png
# Downloaded: sprites\Sprite_0554.png
# Downloaded: sprites\Sprite_0555-Galar.png
# Downloaded: sprites\Sprite_0555-Zen_Galar.png
# Downloaded: sprites\Sprite_0555-Zen.png
# Downloaded: sprites\Sprite_0555.png
# Downloaded: sprites\Sprite_0556.png
# Downloaded: sprites\Sprite_0557.png
# Downloaded: sprites\Sprite_0558.png
# Downloaded: sprites\Sprite_0559.png
# Downloaded: sprites\Sprite_0560.png
# Downloaded: sprites\Sprite_0561.png
# Downloaded: sprites\Sprite_0562-Galar.png
# Downloaded: sprites\Sprite_0562.png
# Downloaded: sprites\Sprite_0563.png
# Downloaded: sprites\Sprite_0564.png
# Downloaded: sprites\Sprite_0565.png
# Downloaded: sprites\Sprite_0566.png
# Downloaded: sprites\Sprite_0567.png
# Downloaded: sprites\Sprite_0568.png
# Downloaded: sprites\Sprite_0569.png
# Downloaded: sprites\Sprite_0570-Hisui.png
# Downloaded: sprites\Sprite_0570.png
# Downloaded: sprites\Sprite_0571-Hisui.png
# Downloaded: sprites\Sprite_0571.png
# Downloaded: sprites\Sprite_0572.png
# Downloaded: sprites\Sprite_0573.png
# Downloaded: sprites\Sprite_0574.png
# Downloaded: sprites\Sprite_0575.png
# Downloaded: sprites\Sprite_0576.png
# Downloaded: sprites\Sprite_0577.png
# Downloaded: sprites\Sprite_0578.png
# Downloaded: sprites\Sprite_0579.png
# Downloaded: sprites\Sprite_0580.png
# Downloaded: sprites\Sprite_0581.png
# Downloaded: sprites\Sprite_0582.png
# Downloaded: sprites\Sprite_0583.png
# Downloaded: sprites\Sprite_0584.png
# Downloaded: sprites\Sprite_0585-Autumn.png
# Downloaded: sprites\Sprite_0585-Summer.png
# Downloaded: sprites\Sprite_0585-Winter.png
# Downloaded: sprites\Sprite_0585.png
# Downloaded: sprites\Sprite_0586-Autumn.png
# Downloaded: sprites\Sprite_0586-Summer.png
# Downloaded: sprites\Sprite_0586-Winter.png
# Downloaded: sprites\Sprite_0586.png
# Downloaded: sprites\Sprite_0587.png
# Downloaded: sprites\Sprite_0588.png
# Downloaded: sprites\Sprite_0589.png
# Downloaded: sprites\Sprite_0590.png
# Downloaded: sprites\Sprite_0591.png
# Downloaded: sprites\Sprite_0592-Female.png
# Downloaded: sprites\Sprite_0592.png
# Downloaded: sprites\Sprite_0593-Female.png
# Downloaded: sprites\Sprite_0593.png
# Downloaded: sprites\Sprite_0594.png
# Downloaded: sprites\Sprite_0595.png
# Downloaded: sprites\Sprite_0596.png
# Downloaded: sprites\Sprite_0597.png
# Downloaded: sprites\Sprite_0598.png
# Downloaded: sprites\Sprite_0599.png
# Downloaded: sprites\Sprite_0600.png
# Downloaded: sprites\Sprite_0601.png
# Downloaded: sprites\Sprite_0602.png
# Downloaded: sprites\Sprite_0603.png
# Downloaded: sprites\Sprite_0604.png
# Downloaded: sprites\Sprite_0605.png
# Downloaded: sprites\Sprite_0606.png
# Downloaded: sprites\Sprite_0607.png
# Downloaded: sprites\Sprite_0608.png
# Downloaded: sprites\Sprite_0609.png
# Downloaded: sprites\Sprite_0610.png
# Downloaded: sprites\Sprite_0611.png
# Downloaded: sprites\Sprite_0612.png
# Downloaded: sprites\Sprite_0613.png
#
# Processing page: https://archives.bulbagarden.net/w/index.php?title=Category:HOME_menu_sprites&filefrom=Menu+HOME+0614.png#mw-category-media
# Downloaded: sprites\Sprite_0614.png
# Downloaded: sprites\Sprite_0615.png
# Downloaded: sprites\Sprite_0616.png
# Downloaded: sprites\Sprite_0617.png
# Downloaded: sprites\Sprite_0618-Galar.png
# Downloaded: sprites\Sprite_0618.png
# Downloaded: sprites\Sprite_0619.png
# Downloaded: sprites\Sprite_0620.png
# Downloaded: sprites\Sprite_0621.png
# Downloaded: sprites\Sprite_0622.png
# Downloaded: sprites\Sprite_0623.png
# Downloaded: sprites\Sprite_0624.png
# Downloaded: sprites\Sprite_0625.png
# Downloaded: sprites\Sprite_0626.png
# Downloaded: sprites\Sprite_0627.png
# Downloaded: sprites\Sprite_0628-Hisui.png
# Downloaded: sprites\Sprite_0628.png
# Downloaded: sprites\Sprite_0629.png
# Downloaded: sprites\Sprite_0630.png
# Downloaded: sprites\Sprite_0631.png
# Downloaded: sprites\Sprite_0632.png
# Downloaded: sprites\Sprite_0633.png
# Downloaded: sprites\Sprite_0634.png
# Downloaded: sprites\Sprite_0635.png
# Downloaded: sprites\Sprite_0636.png
# Downloaded: sprites\Sprite_0637.png
# Downloaded: sprites\Sprite_0638.png
# Downloaded: sprites\Sprite_0639.png
# Downloaded: sprites\Sprite_0640.png
# Downloaded: sprites\Sprite_0641-Therian.png
# Downloaded: sprites\Sprite_0641.png
# Downloaded: sprites\Sprite_0642-Therian.png
# Downloaded: sprites\Sprite_0642.png
# Downloaded: sprites\Sprite_0643.png
# Downloaded: sprites\Sprite_0644.png
# Downloaded: sprites\Sprite_0645-Therian.png
# Downloaded: sprites\Sprite_0645.png
# Downloaded: sprites\Sprite_0646-Black.png
# Downloaded: sprites\Sprite_0646-White.png
# Downloaded: sprites\Sprite_0646.png
# Downloaded: sprites\Sprite_0647-Resolute.png
# Downloaded: sprites\Sprite_0647.png
# Downloaded: sprites\Sprite_0648-Pirouette.png
# Downloaded: sprites\Sprite_0648.png
# Downloaded: sprites\Sprite_0649-Burn.png
# Downloaded: sprites\Sprite_0649-Chill.png
# Downloaded: sprites\Sprite_0649-Douse.png
# Downloaded: sprites\Sprite_0649-Shock.png
# Downloaded: sprites\Sprite_0649.png
# Downloaded: sprites\Sprite_0650.png
# Downloaded: sprites\Sprite_0651.png
# Downloaded: sprites\Sprite_0652.png
# Downloaded: sprites\Sprite_0653.png
# Downloaded: sprites\Sprite_0654.png
# Downloaded: sprites\Sprite_0655.png
# Downloaded: sprites\Sprite_0656.png
# Downloaded: sprites\Sprite_0657.png
# Downloaded: sprites\Sprite_0658-Ash.png
# Downloaded: sprites\Sprite_0658.png
# Downloaded: sprites\Sprite_0659.png
# Downloaded: sprites\Sprite_0660.png
# Downloaded: sprites\Sprite_0661.png
# Downloaded: sprites\Sprite_0662.png
# Downloaded: sprites\Sprite_0663.png
# Downloaded: sprites\Sprite_0664.png
# Downloaded: sprites\Sprite_0665.png
# Downloaded: sprites\Sprite_0666-Archipelago.png
# Downloaded: sprites\Sprite_0666-Continental.png
# Downloaded: sprites\Sprite_0666-Elegant.png
# Downloaded: sprites\Sprite_0666-Fancy.png
# Downloaded: sprites\Sprite_0666-Garden.png
# Downloaded: sprites\Sprite_0666-High_Plains.png
# Downloaded: sprites\Sprite_0666-Icy_Snow.png
# Downloaded: sprites\Sprite_0666-Jungle.png
# Downloaded: sprites\Sprite_0666-Marine.png
# Downloaded: sprites\Sprite_0666-Modern.png
# Downloaded: sprites\Sprite_0666-Monsoon.png
# Downloaded: sprites\Sprite_0666-Ocean.png
# Downloaded: sprites\Sprite_0666-Poké_Ball.png
# Downloaded: sprites\Sprite_0666-Polar.png
# Downloaded: sprites\Sprite_0666-River.png
# Downloaded: sprites\Sprite_0666-Sandstorm.png
# Downloaded: sprites\Sprite_0666-Savanna.png
# Downloaded: sprites\Sprite_0666-Sun.png
# Downloaded: sprites\Sprite_0666-Tundra.png
# Downloaded: sprites\Sprite_0666.png
# Downloaded: sprites\Sprite_0667.png
# Downloaded: sprites\Sprite_0668-Female.png
# Downloaded: sprites\Sprite_0668.png
# Downloaded: sprites\Sprite_0669-Blue.png
# Downloaded: sprites\Sprite_0669-Orange.png
# Downloaded: sprites\Sprite_0669-White.png
# Downloaded: sprites\Sprite_0669-Yellow.png
# Downloaded: sprites\Sprite_0669.png
# Downloaded: sprites\Sprite_0670-Blue.png
# Downloaded: sprites\Sprite_0670-Eternal.png
# Downloaded: sprites\Sprite_0670-Orange.png
# Downloaded: sprites\Sprite_0670-White.png
# Downloaded: sprites\Sprite_0670-Yellow.png
# Downloaded: sprites\Sprite_0670.png
# Downloaded: sprites\Sprite_0671-Blue.png
# Downloaded: sprites\Sprite_0671-Orange.png
# Downloaded: sprites\Sprite_0671-White.png
# Downloaded: sprites\Sprite_0671-Yellow.png
# Downloaded: sprites\Sprite_0671.png
# Downloaded: sprites\Sprite_0672.png
# Downloaded: sprites\Sprite_0673.png
# Downloaded: sprites\Sprite_0674.png
# Downloaded: sprites\Sprite_0675.png
# Downloaded: sprites\Sprite_0676-Dandy.png
# Downloaded: sprites\Sprite_0676-Debutante.png
# Downloaded: sprites\Sprite_0676-Diamond.png
# Downloaded: sprites\Sprite_0676-Heart.png
# Downloaded: sprites\Sprite_0676-Kabuki.png
# Downloaded: sprites\Sprite_0676-La_Reine.png
# Downloaded: sprites\Sprite_0676-Matron.png
# Downloaded: sprites\Sprite_0676-Pharaoh.png
# Downloaded: sprites\Sprite_0676-Star.png
# Downloaded: sprites\Sprite_0676.png
# Downloaded: sprites\Sprite_0677.png
# Downloaded: sprites\Sprite_0678-Female.png
# Downloaded: sprites\Sprite_0678.png
# Downloaded: sprites\Sprite_0679.png
# Downloaded: sprites\Sprite_0680.png
# Downloaded: sprites\Sprite_0681-Blade.png
# Downloaded: sprites\Sprite_0681.png
# Downloaded: sprites\Sprite_0682.png
# Downloaded: sprites\Sprite_0683.png
# Downloaded: sprites\Sprite_0684.png
# Downloaded: sprites\Sprite_0685.png
# Downloaded: sprites\Sprite_0686.png
# Downloaded: sprites\Sprite_0687.png
# Downloaded: sprites\Sprite_0688.png
# Downloaded: sprites\Sprite_0689.png
# Downloaded: sprites\Sprite_0690.png
# Downloaded: sprites\Sprite_0691.png
# Downloaded: sprites\Sprite_0692.png
# Downloaded: sprites\Sprite_0693.png
# Downloaded: sprites\Sprite_0694.png
# Downloaded: sprites\Sprite_0695.png
# Downloaded: sprites\Sprite_0696.png
# Downloaded: sprites\Sprite_0697.png
# Downloaded: sprites\Sprite_0698.png
# Downloaded: sprites\Sprite_0699.png
# Downloaded: sprites\Sprite_0700.png
# Downloaded: sprites\Sprite_0701.png
# Downloaded: sprites\Sprite_0702.png
# Downloaded: sprites\Sprite_0703.png
# Downloaded: sprites\Sprite_0704.png
# Downloaded: sprites\Sprite_0705-Hisui.png
# Downloaded: sprites\Sprite_0705.png
# Downloaded: sprites\Sprite_0706-Hisui.png
# Downloaded: sprites\Sprite_0706.png
# Downloaded: sprites\Sprite_0707.png
# Downloaded: sprites\Sprite_0708.png
# Downloaded: sprites\Sprite_0709.png
# Downloaded: sprites\Sprite_0710-Large.png
# Downloaded: sprites\Sprite_0710-Small.png
# Downloaded: sprites\Sprite_0710-Super.png
# Downloaded: sprites\Sprite_0710.png
# Downloaded: sprites\Sprite_0711-Large.png
# Downloaded: sprites\Sprite_0711-Small.png
# Downloaded: sprites\Sprite_0711-Super.png
# Downloaded: sprites\Sprite_0711.png
# Downloaded: sprites\Sprite_0712.png
# Downloaded: sprites\Sprite_0713-Hisui.png
# Downloaded: sprites\Sprite_0713.png
# Downloaded: sprites\Sprite_0714.png
# Downloaded: sprites\Sprite_0715.png
# Downloaded: sprites\Sprite_0716-Neutral.png
# Downloaded: sprites\Sprite_0716.png
# Downloaded: sprites\Sprite_0717.png
# Downloaded: sprites\Sprite_0718-10_Percent.png
# Downloaded: sprites\Sprite_0718-Complete.png
# Downloaded: sprites\Sprite_0718.png
# Downloaded: sprites\Sprite_0719-Mega.png
# Downloaded: sprites\Sprite_0719.png
# Downloaded: sprites\Sprite_0720-Unbound.png
# Downloaded: sprites\Sprite_0720.png
# Downloaded: sprites\Sprite_0721.png
# Downloaded: sprites\Sprite_0722.png
# Downloaded: sprites\Sprite_0723.png
# Downloaded: sprites\Sprite_0724-Hisui.png
# Downloaded: sprites\Sprite_0724.png
# Downloaded: sprites\Sprite_0725.png
# Downloaded: sprites\Sprite_0726.png
# Downloaded: sprites\Sprite_0727.png
# Downloaded: sprites\Sprite_0728.png
# Downloaded: sprites\Sprite_0729.png
# Downloaded: sprites\Sprite_0730.png
# Downloaded: sprites\Sprite_0731.png
# Downloaded: sprites\Sprite_0732.png
# Downloaded: sprites\Sprite_0733.png
# Downloaded: sprites\Sprite_0734.png
# Downloaded: sprites\Sprite_0735.png
# Downloaded: sprites\Sprite_0736.png
# Downloaded: sprites\Sprite_0737.png
# Downloaded: sprites\Sprite_0738.png
# Downloaded: sprites\Sprite_0739.png
# Downloaded: sprites\Sprite_0740.png
#
# Processing page: https://archives.bulbagarden.net/w/index.php?title=Category:HOME_menu_sprites&filefrom=Menu+HOME+0741-Pa%27u.png#mw-category-media
# Downloaded: sprites\Sprite_0741-Sensu.png
# Downloaded: sprites\Sprite_0741.png
# Downloaded: sprites\Sprite_0742.png
# Downloaded: sprites\Sprite_0743.png
# Downloaded: sprites\Sprite_0744.png
# Downloaded: sprites\Sprite_0745-Dusk.png
# Downloaded: sprites\Sprite_0745-Midnight.png
# Downloaded: sprites\Sprite_0745.png
# Downloaded: sprites\Sprite_0746-School.png
# Downloaded: sprites\Sprite_0746.png
# Downloaded: sprites\Sprite_0747.png
# Downloaded: sprites\Sprite_0748.png
# Downloaded: sprites\Sprite_0749.png
# Downloaded: sprites\Sprite_0750.png
# Downloaded: sprites\Sprite_0751.png
# Downloaded: sprites\Sprite_0752.png
# Downloaded: sprites\Sprite_0753.png
# Downloaded: sprites\Sprite_0754.png
# Downloaded: sprites\Sprite_0755.png
# Downloaded: sprites\Sprite_0756.png
# Downloaded: sprites\Sprite_0757.png
# Downloaded: sprites\Sprite_0758.png
# Downloaded: sprites\Sprite_0759.png
# Downloaded: sprites\Sprite_0760.png
# Downloaded: sprites\Sprite_0761.png
# Downloaded: sprites\Sprite_0762.png
# Downloaded: sprites\Sprite_0763.png
# Downloaded: sprites\Sprite_0764.png
# Downloaded: sprites\Sprite_0765.png
# Downloaded: sprites\Sprite_0766.png
# Downloaded: sprites\Sprite_0767.png
# Downloaded: sprites\Sprite_0768.png
# Downloaded: sprites\Sprite_0769.png
# Downloaded: sprites\Sprite_0770.png
# Downloaded: sprites\Sprite_0771.png
# Downloaded: sprites\Sprite_0772.png
# Downloaded: sprites\Sprite_0773.png
# Downloaded: sprites\Sprite_0774-Blue.png
# Downloaded: sprites\Sprite_0774-Green.png
# Downloaded: sprites\Sprite_0774-Indigo.png
# Downloaded: sprites\Sprite_0774-Orange.png
# Downloaded: sprites\Sprite_0774-Red.png
# Downloaded: sprites\Sprite_0774-Violet.png
# Downloaded: sprites\Sprite_0774-Yellow.png
# Downloaded: sprites\Sprite_0774.png
# Downloaded: sprites\Sprite_0775.png
# Downloaded: sprites\Sprite_0776.png
# Downloaded: sprites\Sprite_0777.png
# Downloaded: sprites\Sprite_0778.png
# Downloaded: sprites\Sprite_0779.png
# Downloaded: sprites\Sprite_0780.png
# Downloaded: sprites\Sprite_0781.png
# Downloaded: sprites\Sprite_0782.png
# Downloaded: sprites\Sprite_0783.png
# Downloaded: sprites\Sprite_0784.png
# Downloaded: sprites\Sprite_0785.png
# Downloaded: sprites\Sprite_0786.png
# Downloaded: sprites\Sprite_0787.png
# Downloaded: sprites\Sprite_0788.png
# Downloaded: sprites\Sprite_0789.png
# Downloaded: sprites\Sprite_0790.png
# Downloaded: sprites\Sprite_0791.png
# Downloaded: sprites\Sprite_0792.png
# Downloaded: sprites\Sprite_0793.png
# Downloaded: sprites\Sprite_0794.png
# Downloaded: sprites\Sprite_0795.png
# Downloaded: sprites\Sprite_0796.png
# Downloaded: sprites\Sprite_0797.png
# Downloaded: sprites\Sprite_0798.png
# Downloaded: sprites\Sprite_0799.png
# Downloaded: sprites\Sprite_0800-Dawn_Wings.png
# Downloaded: sprites\Sprite_0800-Dusk_Mane.png
# Downloaded: sprites\Sprite_0800-Ultra.png
# Downloaded: sprites\Sprite_0800.png
# Downloaded: sprites\Sprite_0801-Original_Color.png
# Downloaded: sprites\Sprite_0801.png
# Downloaded: sprites\Sprite_0802.png
# Downloaded: sprites\Sprite_0803.png
# Downloaded: sprites\Sprite_0804.png
# Downloaded: sprites\Sprite_0805.png
# Downloaded: sprites\Sprite_0806.png
# Downloaded: sprites\Sprite_0807.png
# Downloaded: sprites\Sprite_0808.png
# Downloaded: sprites\Sprite_0809.png
# Downloaded: sprites\Sprite_0810.png
# Downloaded: sprites\Sprite_0811.png
# Downloaded: sprites\Sprite_0812.png
# Downloaded: sprites\Sprite_0813.png
# Downloaded: sprites\Sprite_0814.png
# Downloaded: sprites\Sprite_0815.png
# Downloaded: sprites\Sprite_0816.png
# Downloaded: sprites\Sprite_0817.png
# Downloaded: sprites\Sprite_0818.png
# Downloaded: sprites\Sprite_0819.png
# Downloaded: sprites\Sprite_0820.png
# Downloaded: sprites\Sprite_0821.png
# Downloaded: sprites\Sprite_0822.png
# Downloaded: sprites\Sprite_0823.png
# Downloaded: sprites\Sprite_0824.png
# Downloaded: sprites\Sprite_0825.png
# Downloaded: sprites\Sprite_0826.png
# Downloaded: sprites\Sprite_0827.png
# Downloaded: sprites\Sprite_0828.png
# Downloaded: sprites\Sprite_0829.png
# Downloaded: sprites\Sprite_0830.png
# Downloaded: sprites\Sprite_0831.png
# Downloaded: sprites\Sprite_0832.png
# Downloaded: sprites\Sprite_0833.png
# Downloaded: sprites\Sprite_0834.png
# Downloaded: sprites\Sprite_0835.png
# Downloaded: sprites\Sprite_0836.png
# Downloaded: sprites\Sprite_0837.png
# Downloaded: sprites\Sprite_0838.png
# Downloaded: sprites\Sprite_0839.png
# Downloaded: sprites\Sprite_0840.png
# Downloaded: sprites\Sprite_0841.png
# Downloaded: sprites\Sprite_0842.png
# Downloaded: sprites\Sprite_0843.png
# Downloaded: sprites\Sprite_0844.png
# Downloaded: sprites\Sprite_0845-Gorging.png
# Downloaded: sprites\Sprite_0845-Gulping.png
# Downloaded: sprites\Sprite_0845.png
# Downloaded: sprites\Sprite_0846.png
# Downloaded: sprites\Sprite_0847.png
# Downloaded: sprites\Sprite_0848.png
# Downloaded: sprites\Sprite_0849-Low_Key.png
# Downloaded: sprites\Sprite_0849.png
# Downloaded: sprites\Sprite_0850.png
# Downloaded: sprites\Sprite_0851.png
# Downloaded: sprites\Sprite_0852.png
# Downloaded: sprites\Sprite_0853.png
# Downloaded: sprites\Sprite_0854.png
# Downloaded: sprites\Sprite_0855.png
# Downloaded: sprites\Sprite_0856.png
# Downloaded: sprites\Sprite_0857.png
# Downloaded: sprites\Sprite_0858.png
# Downloaded: sprites\Sprite_0859.png
# Downloaded: sprites\Sprite_0860.png
# Downloaded: sprites\Sprite_0861.png
# Downloaded: sprites\Sprite_0862.png
# Downloaded: sprites\Sprite_0863.png
# Downloaded: sprites\Sprite_0864.png
# Downloaded: sprites\Sprite_0865.png
# Downloaded: sprites\Sprite_0866.png
# Downloaded: sprites\Sprite_0867.png
# Error fetching https://archives.bulbagarden.net/wiki/File:Menu_HOME_0868.png (attempt 1/3): 503 Server Error: Service Unavailable for url: https://archives.bulbagarden.net/wiki/File:Menu_HOME_0868.png
# Downloaded: sprites\Sprite_0868.png
# Downloaded: sprites\Sprite_0869-Caramel.png
# Downloaded: sprites\Sprite_0869-Lemon.png
# Downloaded: sprites\Sprite_0869-Matcha.png
# Downloaded: sprites\Sprite_0869-Mint.png
# Downloaded: sprites\Sprite_0869-Rainbow.png
# Downloaded: sprites\Sprite_0869-Ruby_Swirl.png
# Downloaded: sprites\Sprite_0869-Ruby.png
# Downloaded: sprites\Sprite_0869-Salted.png
# Downloaded: sprites\Sprite_0869.png
# Downloaded: sprites\Sprite_0870.png
# Downloaded: sprites\Sprite_0871.png
# Downloaded: sprites\Sprite_0872.png
# Downloaded: sprites\Sprite_0873.png
# Downloaded: sprites\Sprite_0874.png
# Downloaded: sprites\Sprite_0875-Noice.png
# Downloaded: sprites\Sprite_0875.png
# Downloaded: sprites\Sprite_0876-Female.png
# Downloaded: sprites\Sprite_0876.png
# Downloaded: sprites\Sprite_0877-Hangry.png
# Downloaded: sprites\Sprite_0877.png
# Downloaded: sprites\Sprite_0878.png
# Downloaded: sprites\Sprite_0879.png
# Downloaded: sprites\Sprite_0880.png
# Downloaded: sprites\Sprite_0881.png
# Downloaded: sprites\Sprite_0882.png
# Downloaded: sprites\Sprite_0883.png
# Downloaded: sprites\Sprite_0884.png
# Downloaded: sprites\Sprite_0885.png
# Downloaded: sprites\Sprite_0886.png
# Downloaded: sprites\Sprite_0887.png
# Downloaded: sprites\Sprite_0888-Crowned.png
# Downloaded: sprites\Sprite_0888.png
# Downloaded: sprites\Sprite_0889-Crowned.png
# Error fetching https://archives.bulbagarden.net/wiki/File:Menu_HOME_0889.png (attempt 1/3): 503 Server Error: Service Unavailable for url: https://archives.bulbagarden.net/wiki/File:Menu_HOME_0889.png
# Downloaded: sprites\Sprite_0889.png
# Downloaded: sprites\Sprite_0890.png
# Downloaded: sprites\Sprite_0891.png
# Downloaded: sprites\Sprite_0892.png
# Downloaded: sprites\Sprite_0893-Dada.png
# Downloaded: sprites\Sprite_0893.png
# Downloaded: sprites\Sprite_0894.png
# Downloaded: sprites\Sprite_0895.png
# Downloaded: sprites\Sprite_0896.png
# Downloaded: sprites\Sprite_0897.png
# Downloaded: sprites\Sprite_0898-Ice_Rider.png
# Downloaded: sprites\Sprite_0898-Shadow_Rider.png
# Downloaded: sprites\Sprite_0898.png
# Downloaded: sprites\Sprite_0899.png
# Downloaded: sprites\Sprite_0900.png
# Downloaded: sprites\Sprite_0901-Bloodmoon.png
# Downloaded: sprites\Sprite_0901.png
# Downloaded: sprites\Sprite_0902-Female.png
# Downloaded: sprites\Sprite_0902.png
#
# Processing page: https://archives.bulbagarden.net/w/index.php?title=Category:HOME_menu_sprites&filefrom=Menu+HOME+0903.png#mw-category-media
# Downloaded: sprites\Sprite_0903.png
# Downloaded: sprites\Sprite_0904.png
# Downloaded: sprites\Sprite_0905-Therian.png
# Downloaded: sprites\Sprite_0905.png
# Downloaded: sprites\Sprite_0906.png
# Downloaded: sprites\Sprite_0907.png
# Downloaded: sprites\Sprite_0908.png
# Downloaded: sprites\Sprite_0909.png
# Downloaded: sprites\Sprite_0910.png
# Downloaded: sprites\Sprite_0911.png
# Downloaded: sprites\Sprite_0912.png
# Error fetching https://archives.bulbagarden.net/wiki/File:Menu_HOME_0913.png (attempt 1/3): 503 Server Error: Service Unavailable for url: https://archives.bulbagarden.net/wiki/File:Menu_HOME_0913.png
# Downloaded: sprites\Sprite_0913.png
# Downloaded: sprites\Sprite_0914.png
# Downloaded: sprites\Sprite_0915.png
# Downloaded: sprites\Sprite_0916-Female.png
# Downloaded: sprites\Sprite_0916.png
# Downloaded: sprites\Sprite_0917.png
# Downloaded: sprites\Sprite_0918.png
# Downloaded: sprites\Sprite_0919.png
# Downloaded: sprites\Sprite_0920.png
# Downloaded: sprites\Sprite_0921.png
# Downloaded: sprites\Sprite_0922.png
# Downloaded: sprites\Sprite_0923.png
# Downloaded: sprites\Sprite_0924.png
# Downloaded: sprites\Sprite_0925-Three.png
# Downloaded: sprites\Sprite_0925.png
# Downloaded: sprites\Sprite_0926.png
# Downloaded: sprites\Sprite_0927.png
# Downloaded: sprites\Sprite_0928.png
# Downloaded: sprites\Sprite_0929.png
# Downloaded: sprites\Sprite_0930.png
# Downloaded: sprites\Sprite_0931-Blue.png
# Downloaded: sprites\Sprite_0931-White.png
# Downloaded: sprites\Sprite_0931-Yellow.png
# Downloaded: sprites\Sprite_0931.png
# Downloaded: sprites\Sprite_0932.png
# Downloaded: sprites\Sprite_0933.png
# Downloaded: sprites\Sprite_0934.png
# Downloaded: sprites\Sprite_0935.png
# Downloaded: sprites\Sprite_0936.png
# Error fetching https://archives.bulbagarden.net/wiki/File:Menu_HOME_0937.png (attempt 1/3): 503 Server Error: Service Unavailable for url: https://archives.bulbagarden.net/wiki/File:Menu_HOME_0937.png
# Downloaded: sprites\Sprite_0937.png
# Downloaded: sprites\Sprite_0938.png
# Downloaded: sprites\Sprite_0939.png
# Downloaded: sprites\Sprite_0940.png
# Downloaded: sprites\Sprite_0941.png
# Downloaded: sprites\Sprite_0942.png
# Downloaded: sprites\Sprite_0943.png
# Downloaded: sprites\Sprite_0944.png
# Downloaded: sprites\Sprite_0945.png
# Downloaded: sprites\Sprite_0946.png
# Downloaded: sprites\Sprite_0947.png
# Downloaded: sprites\Sprite_0948.png
# Downloaded: sprites\Sprite_0949.png
# Downloaded: sprites\Sprite_0950.png
# Downloaded: sprites\Sprite_0951.png
# Downloaded: sprites\Sprite_0952.png
# Downloaded: sprites\Sprite_0953.png
# Downloaded: sprites\Sprite_0954.png
# Downloaded: sprites\Sprite_0955.png
# Downloaded: sprites\Sprite_0956.png
# Downloaded: sprites\Sprite_0957.png
# Downloaded: sprites\Sprite_0958.png
# Downloaded: sprites\Sprite_0959.png
# Downloaded: sprites\Sprite_0960.png
# Downloaded: sprites\Sprite_0961.png
# Downloaded: sprites\Sprite_0962.png
# Downloaded: sprites\Sprite_0963.png
# Downloaded: sprites\Sprite_0964-Hero.png
# Downloaded: sprites\Sprite_0964.png
# Downloaded: sprites\Sprite_0965.png
# Downloaded: sprites\Sprite_0966.png
# Downloaded: sprites\Sprite_0967.png
# Downloaded: sprites\Sprite_0968.png
# Downloaded: sprites\Sprite_0969.png
# Downloaded: sprites\Sprite_0970.png
# Error fetching https://archives.bulbagarden.net/wiki/File:Menu_HOME_0971.png (attempt 1/3): 503 Server Error: Service Unavailable for url: https://archives.bulbagarden.net/wiki/File:Menu_HOME_0971.png
# Downloaded: sprites\Sprite_0971.png
# Downloaded: sprites\Sprite_0972.png
# Downloaded: sprites\Sprite_0973.png
# Downloaded: sprites\Sprite_0974.png
# Downloaded: sprites\Sprite_0975.png
# Downloaded: sprites\Sprite_0976.png
# Downloaded: sprites\Sprite_0977.png
# Downloaded: sprites\Sprite_0978-Droopy.png
# Downloaded: sprites\Sprite_0978-Stretchy.png
# Downloaded: sprites\Sprite_0978.png
# Downloaded: sprites\Sprite_0979.png
# Error fetching https://archives.bulbagarden.net/wiki/File:Menu_HOME_0980.png (attempt 1/3): 503 Server Error: Service Unavailable for url: https://archives.bulbagarden.net/wiki/File:Menu_HOME_0980.png
# Downloaded: sprites\Sprite_0980.png
# Downloaded: sprites\Sprite_0981.png
# Downloaded: sprites\Sprite_0982.png
# Downloaded: sprites\Sprite_0983.png
# Downloaded: sprites\Sprite_0984.png
# Downloaded: sprites\Sprite_0985.png
# Downloaded: sprites\Sprite_0986.png
# Downloaded: sprites\Sprite_0987.png
# Downloaded: sprites\Sprite_0988.png
# Downloaded: sprites\Sprite_0989.png
# Downloaded: sprites\Sprite_0990.png
# Downloaded: sprites\Sprite_0991.png
# Downloaded: sprites\Sprite_0992.png
# Downloaded: sprites\Sprite_0993.png
# Downloaded: sprites\Sprite_0994.png
# Downloaded: sprites\Sprite_0995.png
# Downloaded: sprites\Sprite_0996.png
# Downloaded: sprites\Sprite_0997.png
# Downloaded: sprites\Sprite_0998.png
# Downloaded: sprites\Sprite_0999-Roaming.png
# Downloaded: sprites\Sprite_0999.png
# Downloaded: sprites\Sprite_1000.png
# Downloaded: sprites\Sprite_1001.png
# Downloaded: sprites\Sprite_1002.png
# Downloaded: sprites\Sprite_1003.png
# Downloaded: sprites\Sprite_1004.png
# Downloaded: sprites\Sprite_1005.png
# Downloaded: sprites\Sprite_1006.png
# Downloaded: sprites\Sprite_1007-Sprinting.png
# Downloaded: sprites\Sprite_1007.png
# Downloaded: sprites\Sprite_1008-Drive.png
# Downloaded: sprites\Sprite_1008.png
# Downloaded: sprites\Sprite_1009.png
# Downloaded: sprites\Sprite_1010.png
# Downloaded: sprites\Sprite_1011.png
# Downloaded: sprites\Sprite_1012.png
# Downloaded: sprites\Sprite_1013.png
# Downloaded: sprites\Sprite_1014.png
# Downloaded: sprites\Sprite_1015.png
# Downloaded: sprites\Sprite_1016.png
# Downloaded: sprites\Sprite_1017-Cornerstone_Mask.png
# Downloaded: sprites\Sprite_1017-Hearthflame_Mask.png
# Downloaded: sprites\Sprite_1017-Wellspring_Mask.png
# Downloaded: sprites\Sprite_1017.png
# Downloaded: sprites\Sprite_1018.png
# Downloaded: sprites\Sprite_1019.png
# Downloaded: sprites\Sprite_1020.png
# Downloaded: sprites\Sprite_1021.png
# Downloaded: sprites\Sprite_1022.png
# Downloaded: sprites\Sprite_1023.png
# Downloaded: sprites\Sprite_1024.png
# Downloaded: sprites\Sprite_1025.png

# %%
import os
import shutil
import re

sprites_dir = "sprites"
national_dir = os.path.join(sprites_dir, "national")
os.makedirs(national_dir, exist_ok=True)

for filename in os.listdir(sprites_dir):
    if filename.endswith(".png") and filename.startswith("Sprite_"):
        match = re.match(r"Sprite_(\d{4})(?:-([\w]+))?\.png", filename)
        if match:
            _, form = match.groups()
            if form:
                target_dir = os.path.join(sprites_dir, form)
            else:
                target_dir = national_dir
            os.makedirs(target_dir, exist_ok=True)

            src_path = os.path.join(sprites_dir, filename)
            dst_path = os.path.join(target_dir, filename)
            shutil.move(src_path, dst_path)
            print(f"Moved: {filename} → {target_dir}")
# Out:
# Moved: Sprite_0001.png → sprites\national
# Moved: Sprite_0002.png → sprites\national
# Moved: Sprite_0003-Mega.png → sprites\Mega
# Moved: Sprite_0003.png → sprites\national
# Moved: Sprite_0004.png → sprites\national
# Moved: Sprite_0005.png → sprites\national
# Moved: Sprite_0006-Mega_X.png → sprites\Mega_X
# Moved: Sprite_0006-Mega_Y.png → sprites\Mega_Y
# Moved: Sprite_0006.png → sprites\national
# Moved: Sprite_0007.png → sprites\national
# Moved: Sprite_0008.png → sprites\national
# Moved: Sprite_0009-Mega.png → sprites\Mega
# Moved: Sprite_0009.png → sprites\national
# Moved: Sprite_0010.png → sprites\national
# Moved: Sprite_0011.png → sprites\national
# Moved: Sprite_0012.png → sprites\national
# Moved: Sprite_0013.png → sprites\national
# Moved: Sprite_0014.png → sprites\national
# Moved: Sprite_0015-Mega.png → sprites\Mega
# Moved: Sprite_0015.png → sprites\national
# Moved: Sprite_0016.png → sprites\national
# Moved: Sprite_0017.png → sprites\national
# Moved: Sprite_0018-Mega.png → sprites\Mega
# Moved: Sprite_0018.png → sprites\national
# Moved: Sprite_0019-Alola.png → sprites\Alola
# Moved: Sprite_0019.png → sprites\national
# Moved: Sprite_0020-Alola.png → sprites\Alola
# Moved: Sprite_0020.png → sprites\national
# Moved: Sprite_0021.png → sprites\national
# Moved: Sprite_0022.png → sprites\national
# Moved: Sprite_0023.png → sprites\national
# Moved: Sprite_0024.png → sprites\national
# Moved: Sprite_0025-Alola.png → sprites\Alola
# Moved: Sprite_0025-Hoenn.png → sprites\Hoenn
# Moved: Sprite_0025-Kalos.png → sprites\Kalos
# Moved: Sprite_0025-Original.png → sprites\Original
# Moved: Sprite_0025-Partner.png → sprites\Partner
# Moved: Sprite_0025-Sinnoh.png → sprites\Sinnoh
# Moved: Sprite_0025-Unova.png → sprites\Unova
# Moved: Sprite_0025-World.png → sprites\World
# Moved: Sprite_0025.png → sprites\national
# Moved: Sprite_0026-Alola.png → sprites\Alola
# Moved: Sprite_0026.png → sprites\national
# Moved: Sprite_0027-Alola.png → sprites\Alola
# Moved: Sprite_0027.png → sprites\national
# Moved: Sprite_0028-Alola.png → sprites\Alola
# Moved: Sprite_0028.png → sprites\national
# Moved: Sprite_0029.png → sprites\national
# Moved: Sprite_0030.png → sprites\national
# Moved: Sprite_0031.png → sprites\national
# Moved: Sprite_0032.png → sprites\national
# Moved: Sprite_0033.png → sprites\national
# Moved: Sprite_0034.png → sprites\national
# Moved: Sprite_0035.png → sprites\national
# Moved: Sprite_0036.png → sprites\national
# Moved: Sprite_0037-Alola.png → sprites\Alola
# Moved: Sprite_0037.png → sprites\national
# Moved: Sprite_0038-Alola.png → sprites\Alola
# Moved: Sprite_0038.png → sprites\national
# Moved: Sprite_0039.png → sprites\national
# Moved: Sprite_0040.png → sprites\national
# Moved: Sprite_0041.png → sprites\national
# Moved: Sprite_0042.png → sprites\national
# Moved: Sprite_0043.png → sprites\national
# Moved: Sprite_0044.png → sprites\national
# Moved: Sprite_0045.png → sprites\national
# Moved: Sprite_0046.png → sprites\national
# Moved: Sprite_0047.png → sprites\national
# Moved: Sprite_0048.png → sprites\national
# Moved: Sprite_0049.png → sprites\national
# Moved: Sprite_0050-Alola.png → sprites\Alola
# Moved: Sprite_0050.png → sprites\national
# Moved: Sprite_0051-Alola.png → sprites\Alola
# Moved: Sprite_0051.png → sprites\national
# Moved: Sprite_0052-Alola.png → sprites\Alola
# Moved: Sprite_0052-Galar.png → sprites\Galar
# Moved: Sprite_0052.png → sprites\national
# Moved: Sprite_0053-Alola.png → sprites\Alola
# Moved: Sprite_0053.png → sprites\national
# Moved: Sprite_0054.png → sprites\national
# Moved: Sprite_0055.png → sprites\national
# Moved: Sprite_0056.png → sprites\national
# Moved: Sprite_0057.png → sprites\national
# Moved: Sprite_0058-Hisui.png → sprites\Hisui
# Moved: Sprite_0058.png → sprites\national
# Moved: Sprite_0059-Hisui.png → sprites\Hisui
# Moved: Sprite_0059.png → sprites\national
# Moved: Sprite_0060.png → sprites\national
# Moved: Sprite_0061.png → sprites\national
# Moved: Sprite_0062.png → sprites\national
# Moved: Sprite_0063.png → sprites\national
# Moved: Sprite_0064.png → sprites\national
# Moved: Sprite_0065-Mega.png → sprites\Mega
# Moved: Sprite_0065.png → sprites\national
# Moved: Sprite_0066.png → sprites\national
# Moved: Sprite_0067.png → sprites\national
# Moved: Sprite_0068.png → sprites\national
# Moved: Sprite_0069.png → sprites\national
# Moved: Sprite_0070.png → sprites\national
# Moved: Sprite_0071.png → sprites\national
# Moved: Sprite_0072.png → sprites\national
# Moved: Sprite_0073.png → sprites\national
# Moved: Sprite_0074-Alola.png → sprites\Alola
# Moved: Sprite_0074.png → sprites\national
# Moved: Sprite_0075-Alola.png → sprites\Alola
# Moved: Sprite_0075.png → sprites\national
# Moved: Sprite_0076-Alola.png → sprites\Alola
# Moved: Sprite_0076.png → sprites\national
# Moved: Sprite_0077-Galar.png → sprites\Galar
# Moved: Sprite_0077.png → sprites\national
# Moved: Sprite_0078-Galar.png → sprites\Galar
# Moved: Sprite_0078.png → sprites\national
# Moved: Sprite_0079-Galar.png → sprites\Galar
# Moved: Sprite_0079.png → sprites\national
# Moved: Sprite_0080-Galar.png → sprites\Galar
# Moved: Sprite_0080-Mega.png → sprites\Mega
# Moved: Sprite_0080.png → sprites\national
# Moved: Sprite_0081.png → sprites\national
# Moved: Sprite_0082.png → sprites\national
# Moved: Sprite_0083-Galar.png → sprites\Galar
# Moved: Sprite_0083.png → sprites\national
# Moved: Sprite_0084.png → sprites\national
# Moved: Sprite_0085.png → sprites\national
# Moved: Sprite_0086.png → sprites\national
# Moved: Sprite_0087.png → sprites\national
# Moved: Sprite_0088-Alola.png → sprites\Alola
# Moved: Sprite_0088.png → sprites\national
# Moved: Sprite_0089-Alola.png → sprites\Alola
# Moved: Sprite_0089.png → sprites\national
# Moved: Sprite_0090.png → sprites\national
# Moved: Sprite_0091.png → sprites\national
# Moved: Sprite_0092.png → sprites\national
# Moved: Sprite_0093.png → sprites\national
# Moved: Sprite_0094-Mega.png → sprites\Mega
# Moved: Sprite_0094.png → sprites\national
# Moved: Sprite_0095.png → sprites\national
# Moved: Sprite_0096.png → sprites\national
# Moved: Sprite_0097.png → sprites\national
# Moved: Sprite_0098.png → sprites\national
# Moved: Sprite_0099.png → sprites\national
# Moved: Sprite_0100-Hisui.png → sprites\Hisui
# Moved: Sprite_0100.png → sprites\national
# Moved: Sprite_0101-Hisui.png → sprites\Hisui
# Moved: Sprite_0101.png → sprites\national
# Moved: Sprite_0102.png → sprites\national
# Moved: Sprite_0103-Alola.png → sprites\Alola
# Moved: Sprite_0103.png → sprites\national
# Moved: Sprite_0104.png → sprites\national
# Moved: Sprite_0105-Alola.png → sprites\Alola
# Moved: Sprite_0105.png → sprites\national
# Moved: Sprite_0106.png → sprites\national
# Moved: Sprite_0107.png → sprites\national
# Moved: Sprite_0108.png → sprites\national
# Moved: Sprite_0109.png → sprites\national
# Moved: Sprite_0110-Galar.png → sprites\Galar
# Moved: Sprite_0110.png → sprites\national
# Moved: Sprite_0111.png → sprites\national
# Moved: Sprite_0112.png → sprites\national
# Moved: Sprite_0113.png → sprites\national
# Moved: Sprite_0114.png → sprites\national
# Moved: Sprite_0115-Mega.png → sprites\Mega
# Moved: Sprite_0115.png → sprites\national
# Moved: Sprite_0116.png → sprites\national
# Moved: Sprite_0117.png → sprites\national
# Moved: Sprite_0118.png → sprites\national
# Moved: Sprite_0119.png → sprites\national
# Moved: Sprite_0120.png → sprites\national
# Moved: Sprite_0121.png → sprites\national
# Moved: Sprite_0122-Galar.png → sprites\Galar
# Moved: Sprite_0122.png → sprites\national
# Moved: Sprite_0123.png → sprites\national
# Moved: Sprite_0124.png → sprites\national
# Moved: Sprite_0125.png → sprites\national
# Moved: Sprite_0126.png → sprites\national
# Moved: Sprite_0127-Mega.png → sprites\Mega
# Moved: Sprite_0127.png → sprites\national
# Moved: Sprite_0128-Paldea_Aqua.png → sprites\Paldea_Aqua
# Moved: Sprite_0128-Paldea_Blaze.png → sprites\Paldea_Blaze
# Moved: Sprite_0128-Paldea_Combat.png → sprites\Paldea_Combat
# Moved: Sprite_0128.png → sprites\national
# Moved: Sprite_0129.png → sprites\national
# Moved: Sprite_0130-Mega.png → sprites\Mega
# Moved: Sprite_0130.png → sprites\national
# Moved: Sprite_0131.png → sprites\national
# Moved: Sprite_0132.png → sprites\national
# Moved: Sprite_0133.png → sprites\national
# Moved: Sprite_0134.png → sprites\national
# Moved: Sprite_0135.png → sprites\national
# Moved: Sprite_0136.png → sprites\national
# Moved: Sprite_0137.png → sprites\national
# Moved: Sprite_0138.png → sprites\national
# Moved: Sprite_0139.png → sprites\national
# Moved: Sprite_0140.png → sprites\national
# Moved: Sprite_0141.png → sprites\national
# Moved: Sprite_0142-Mega.png → sprites\Mega
# Moved: Sprite_0142.png → sprites\national
# Moved: Sprite_0143.png → sprites\national
# Moved: Sprite_0144-Galar.png → sprites\Galar
# Moved: Sprite_0144.png → sprites\national
# Moved: Sprite_0145-Galar.png → sprites\Galar
# Moved: Sprite_0145.png → sprites\national
# Moved: Sprite_0146-Galar.png → sprites\Galar
# Moved: Sprite_0146.png → sprites\national
# Moved: Sprite_0147.png → sprites\national
# Moved: Sprite_0148.png → sprites\national
# Moved: Sprite_0149.png → sprites\national
# Moved: Sprite_0150-Mega_X.png → sprites\Mega_X
# Moved: Sprite_0150-Mega_Y.png → sprites\Mega_Y
# Moved: Sprite_0150.png → sprites\national
# Moved: Sprite_0151.png → sprites\national
# Moved: Sprite_0152.png → sprites\national
# Moved: Sprite_0153.png → sprites\national
# Moved: Sprite_0154.png → sprites\national
# Moved: Sprite_0155.png → sprites\national
# Moved: Sprite_0156.png → sprites\national
# Moved: Sprite_0157-Hisui.png → sprites\Hisui
# Moved: Sprite_0157.png → sprites\national
# Moved: Sprite_0158.png → sprites\national
# Moved: Sprite_0159.png → sprites\national
# Moved: Sprite_0160.png → sprites\national
# Moved: Sprite_0161.png → sprites\national
# Moved: Sprite_0162.png → sprites\national
# Moved: Sprite_0163.png → sprites\national
# Moved: Sprite_0164.png → sprites\national
# Moved: Sprite_0165.png → sprites\national
# Moved: Sprite_0166.png → sprites\national
# Moved: Sprite_0167.png → sprites\national
# Moved: Sprite_0168.png → sprites\national
# Moved: Sprite_0169.png → sprites\national
# Moved: Sprite_0170.png → sprites\national
# Moved: Sprite_0171.png → sprites\national
# Moved: Sprite_0172.png → sprites\national
# Moved: Sprite_0173.png → sprites\national
# Moved: Sprite_0174.png → sprites\national
# Moved: Sprite_0175.png → sprites\national
# Moved: Sprite_0176.png → sprites\national
# Moved: Sprite_0177.png → sprites\national
# Moved: Sprite_0178.png → sprites\national
# Moved: Sprite_0179.png → sprites\national
# Moved: Sprite_0180.png → sprites\national
# Moved: Sprite_0181-Mega.png → sprites\Mega
# Moved: Sprite_0181.png → sprites\national
# Moved: Sprite_0182.png → sprites\national
# Moved: Sprite_0183.png → sprites\national
# Moved: Sprite_0184.png → sprites\national
# Moved: Sprite_0185.png → sprites\national
# Moved: Sprite_0186.png → sprites\national
# Moved: Sprite_0187.png → sprites\national
# Moved: Sprite_0188.png → sprites\national
# Moved: Sprite_0189.png → sprites\national
# Moved: Sprite_0190.png → sprites\national
# Moved: Sprite_0191.png → sprites\national
# Moved: Sprite_0192.png → sprites\national
# Moved: Sprite_0193.png → sprites\national
# Moved: Sprite_0194-Paldea.png → sprites\Paldea
# Moved: Sprite_0194.png → sprites\national
# Moved: Sprite_0195.png → sprites\national
# Moved: Sprite_0196.png → sprites\national
# Moved: Sprite_0197.png → sprites\national
# Moved: Sprite_0198.png → sprites\national
# Moved: Sprite_0199-Galar.png → sprites\Galar
# Moved: Sprite_0199.png → sprites\national
# Moved: Sprite_0200.png → sprites\national
# Moved: Sprite_0201-B.png → sprites\B
# Moved: Sprite_0201-C.png → sprites\C
# Moved: Sprite_0201-D.png → sprites\D
# Moved: Sprite_0201-E.png → sprites\E
# Moved: Sprite_0201-Exclamation.png → sprites\Exclamation
# Moved: Sprite_0201-F.png → sprites\F
# Moved: Sprite_0201-G.png → sprites\G
# Moved: Sprite_0201-H.png → sprites\H
# Moved: Sprite_0201-I.png → sprites\I
# Moved: Sprite_0201-J.png → sprites\J
# Moved: Sprite_0201-K.png → sprites\K
# Moved: Sprite_0201-L.png → sprites\L
# Moved: Sprite_0201-M.png → sprites\M
# Moved: Sprite_0201-N.png → sprites\N
# Moved: Sprite_0201-O.png → sprites\O
# Moved: Sprite_0201-P.png → sprites\P
# Moved: Sprite_0201-Q.png → sprites\Q
# Moved: Sprite_0201-Question.png → sprites\Question
# Moved: Sprite_0201-R.png → sprites\R
# Moved: Sprite_0201-S.png → sprites\S
# Moved: Sprite_0201-T.png → sprites\T
# Moved: Sprite_0201-U.png → sprites\U
# Moved: Sprite_0201-V.png → sprites\V
# Moved: Sprite_0201-W.png → sprites\W
# Moved: Sprite_0201-X.png → sprites\X
# Moved: Sprite_0201-Y.png → sprites\Y
# Moved: Sprite_0201-Z.png → sprites\Z
# Moved: Sprite_0201.png → sprites\national
# Moved: Sprite_0202.png → sprites\national
# Moved: Sprite_0203.png → sprites\national
# Moved: Sprite_0204.png → sprites\national
# Moved: Sprite_0205.png → sprites\national
# Moved: Sprite_0206.png → sprites\national
# Moved: Sprite_0207.png → sprites\national
# Moved: Sprite_0208-Mega.png → sprites\Mega
# Moved: Sprite_0208.png → sprites\national
# Moved: Sprite_0209.png → sprites\national
# Moved: Sprite_0210.png → sprites\national
# Moved: Sprite_0211-Hisui.png → sprites\Hisui
# Moved: Sprite_0211.png → sprites\national
# Moved: Sprite_0212-Mega.png → sprites\Mega
# Moved: Sprite_0212.png → sprites\national
# Moved: Sprite_0213.png → sprites\national
# Moved: Sprite_0214-Mega.png → sprites\Mega
# Moved: Sprite_0214.png → sprites\national
# Moved: Sprite_0215-Hisui.png → sprites\Hisui
# Moved: Sprite_0215.png → sprites\national
# Moved: Sprite_0216.png → sprites\national
# Moved: Sprite_0217.png → sprites\national
# Moved: Sprite_0218.png → sprites\national
# Moved: Sprite_0219.png → sprites\national
# Moved: Sprite_0220.png → sprites\national
# Moved: Sprite_0221.png → sprites\national
# Moved: Sprite_0222-Galar.png → sprites\Galar
# Moved: Sprite_0222.png → sprites\national
# Moved: Sprite_0223.png → sprites\national
# Moved: Sprite_0224.png → sprites\national
# Moved: Sprite_0225.png → sprites\national
# Moved: Sprite_0226.png → sprites\national
# Moved: Sprite_0227.png → sprites\national
# Moved: Sprite_0228.png → sprites\national
# Moved: Sprite_0229-Mega.png → sprites\Mega
# Moved: Sprite_0229.png → sprites\national
# Moved: Sprite_0230.png → sprites\national
# Moved: Sprite_0231.png → sprites\national
# Moved: Sprite_0232.png → sprites\national
# Moved: Sprite_0233.png → sprites\national
# Moved: Sprite_0234.png → sprites\national
# Moved: Sprite_0235.png → sprites\national
# Moved: Sprite_0236.png → sprites\national
# Moved: Sprite_0237.png → sprites\national
# Moved: Sprite_0238.png → sprites\national
# Moved: Sprite_0239.png → sprites\national
# Moved: Sprite_0240.png → sprites\national
# Moved: Sprite_0241.png → sprites\national
# Moved: Sprite_0242.png → sprites\national
# Moved: Sprite_0243.png → sprites\national
# Moved: Sprite_0244.png → sprites\national
# Moved: Sprite_0245.png → sprites\national
# Moved: Sprite_0246.png → sprites\national
# Moved: Sprite_0247.png → sprites\national
# Moved: Sprite_0248-Mega.png → sprites\Mega
# Moved: Sprite_0248.png → sprites\national
# Moved: Sprite_0249.png → sprites\national
# Moved: Sprite_0250.png → sprites\national
# Moved: Sprite_0251.png → sprites\national
# Moved: Sprite_0252.png → sprites\national
# Moved: Sprite_0253.png → sprites\national
# Moved: Sprite_0254-Mega.png → sprites\Mega
# Moved: Sprite_0254.png → sprites\national
# Moved: Sprite_0255.png → sprites\national
# Moved: Sprite_0256.png → sprites\national
# Moved: Sprite_0257-Mega.png → sprites\Mega
# Moved: Sprite_0257.png → sprites\national
# Moved: Sprite_0258.png → sprites\national
# Moved: Sprite_0259.png → sprites\national
# Moved: Sprite_0260-Mega.png → sprites\Mega
# Moved: Sprite_0260.png → sprites\national
# Moved: Sprite_0261.png → sprites\national
# Moved: Sprite_0262.png → sprites\national
# Moved: Sprite_0263-Galar.png → sprites\Galar
# Moved: Sprite_0263.png → sprites\national
# Moved: Sprite_0264-Galar.png → sprites\Galar
# Moved: Sprite_0264.png → sprites\national
# Moved: Sprite_0265.png → sprites\national
# Moved: Sprite_0266.png → sprites\national
# Moved: Sprite_0267.png → sprites\national
# Moved: Sprite_0268.png → sprites\national
# Moved: Sprite_0269.png → sprites\national
# Moved: Sprite_0270.png → sprites\national
# Moved: Sprite_0271.png → sprites\national
# Moved: Sprite_0272.png → sprites\national
# Moved: Sprite_0273.png → sprites\national
# Moved: Sprite_0274.png → sprites\national
# Moved: Sprite_0275.png → sprites\national
# Moved: Sprite_0276.png → sprites\national
# Moved: Sprite_0277.png → sprites\national
# Moved: Sprite_0278.png → sprites\national
# Moved: Sprite_0279.png → sprites\national
# Moved: Sprite_0280.png → sprites\national
# Moved: Sprite_0281.png → sprites\national
# Moved: Sprite_0282-Mega.png → sprites\Mega
# Moved: Sprite_0282.png → sprites\national
# Moved: Sprite_0283.png → sprites\national
# Moved: Sprite_0284.png → sprites\national
# Moved: Sprite_0285.png → sprites\national
# Moved: Sprite_0286.png → sprites\national
# Moved: Sprite_0287.png → sprites\national
# Moved: Sprite_0288.png → sprites\national
# Moved: Sprite_0289.png → sprites\national
# Moved: Sprite_0290.png → sprites\national
# Moved: Sprite_0291.png → sprites\national
# Moved: Sprite_0292.png → sprites\national
# Moved: Sprite_0293.png → sprites\national
# Moved: Sprite_0294.png → sprites\national
# Moved: Sprite_0295.png → sprites\national
# Moved: Sprite_0296.png → sprites\national
# Moved: Sprite_0297.png → sprites\national
# Moved: Sprite_0298.png → sprites\national
# Moved: Sprite_0299.png → sprites\national
# Moved: Sprite_0300.png → sprites\national
# Moved: Sprite_0301.png → sprites\national
# Moved: Sprite_0302-Mega.png → sprites\Mega
# Moved: Sprite_0302.png → sprites\national
# Moved: Sprite_0303-Mega.png → sprites\Mega
# Moved: Sprite_0303.png → sprites\national
# Moved: Sprite_0304.png → sprites\national
# Moved: Sprite_0305.png → sprites\national
# Moved: Sprite_0306-Mega.png → sprites\Mega
# Moved: Sprite_0306.png → sprites\national
# Moved: Sprite_0307.png → sprites\national
# Moved: Sprite_0308-Mega.png → sprites\Mega
# Moved: Sprite_0308.png → sprites\national
# Moved: Sprite_0309.png → sprites\national
# Moved: Sprite_0310-Mega.png → sprites\Mega
# Moved: Sprite_0310.png → sprites\national
# Moved: Sprite_0311.png → sprites\national
# Moved: Sprite_0312.png → sprites\national
# Moved: Sprite_0313.png → sprites\national
# Moved: Sprite_0314.png → sprites\national
# Moved: Sprite_0315.png → sprites\national
# Moved: Sprite_0316.png → sprites\national
# Moved: Sprite_0317.png → sprites\national
# Moved: Sprite_0318.png → sprites\national
# Moved: Sprite_0319-Mega.png → sprites\Mega
# Moved: Sprite_0319.png → sprites\national
# Moved: Sprite_0320.png → sprites\national
# Moved: Sprite_0321.png → sprites\national
# Moved: Sprite_0322.png → sprites\national
# Moved: Sprite_0323-Mega.png → sprites\Mega
# Moved: Sprite_0323.png → sprites\national
# Moved: Sprite_0324.png → sprites\national
# Moved: Sprite_0325.png → sprites\national
# Moved: Sprite_0326.png → sprites\national
# Moved: Sprite_0327.png → sprites\national
# Moved: Sprite_0328.png → sprites\national
# Moved: Sprite_0329.png → sprites\national
# Moved: Sprite_0330.png → sprites\national
# Moved: Sprite_0331.png → sprites\national
# Moved: Sprite_0332.png → sprites\national
# Moved: Sprite_0333.png → sprites\national
# Moved: Sprite_0334-Mega.png → sprites\Mega
# Moved: Sprite_0334.png → sprites\national
# Moved: Sprite_0335.png → sprites\national
# Moved: Sprite_0336.png → sprites\national
# Moved: Sprite_0337.png → sprites\national
# Moved: Sprite_0338.png → sprites\national
# Moved: Sprite_0339.png → sprites\national
# Moved: Sprite_0340.png → sprites\national
# Moved: Sprite_0341.png → sprites\national
# Moved: Sprite_0342.png → sprites\national
# Moved: Sprite_0343.png → sprites\national
# Moved: Sprite_0344.png → sprites\national
# Moved: Sprite_0345.png → sprites\national
# Moved: Sprite_0346.png → sprites\national
# Moved: Sprite_0347.png → sprites\national
# Moved: Sprite_0348.png → sprites\national
# Moved: Sprite_0349.png → sprites\national
# Moved: Sprite_0350.png → sprites\national
# Moved: Sprite_0351-Rainy.png → sprites\Rainy
# Moved: Sprite_0351-Snowy.png → sprites\Snowy
# Moved: Sprite_0351-Sunny.png → sprites\Sunny
# Moved: Sprite_0351.png → sprites\national
# Moved: Sprite_0352.png → sprites\national
# Moved: Sprite_0353.png → sprites\national
# Moved: Sprite_0354-Mega.png → sprites\Mega
# Moved: Sprite_0354.png → sprites\national
# Moved: Sprite_0355.png → sprites\national
# Moved: Sprite_0356.png → sprites\national
# Moved: Sprite_0357.png → sprites\national
# Moved: Sprite_0358.png → sprites\national
# Moved: Sprite_0359-Mega.png → sprites\Mega
# Moved: Sprite_0359.png → sprites\national
# Moved: Sprite_0360.png → sprites\national
# Moved: Sprite_0361.png → sprites\national
# Moved: Sprite_0362-Mega.png → sprites\Mega
# Moved: Sprite_0362.png → sprites\national
# Moved: Sprite_0363.png → sprites\national
# Moved: Sprite_0364.png → sprites\national
# Moved: Sprite_0365.png → sprites\national
# Moved: Sprite_0366.png → sprites\national
# Moved: Sprite_0367.png → sprites\national
# Moved: Sprite_0368.png → sprites\national
# Moved: Sprite_0369.png → sprites\national
# Moved: Sprite_0370.png → sprites\national
# Moved: Sprite_0371.png → sprites\national
# Moved: Sprite_0372.png → sprites\national
# Moved: Sprite_0373-Mega.png → sprites\Mega
# Moved: Sprite_0373.png → sprites\national
# Moved: Sprite_0374.png → sprites\national
# Moved: Sprite_0375.png → sprites\national
# Moved: Sprite_0376-Mega.png → sprites\Mega
# Moved: Sprite_0376.png → sprites\national
# Moved: Sprite_0377.png → sprites\national
# Moved: Sprite_0378.png → sprites\national
# Moved: Sprite_0379.png → sprites\national
# Moved: Sprite_0380-Mega.png → sprites\Mega
# Moved: Sprite_0380.png → sprites\national
# Moved: Sprite_0381-Mega.png → sprites\Mega
# Moved: Sprite_0381.png → sprites\national
# Moved: Sprite_0382-Primal.png → sprites\Primal
# Moved: Sprite_0382.png → sprites\national
# Moved: Sprite_0383-Primal.png → sprites\Primal
# Moved: Sprite_0383.png → sprites\national
# Moved: Sprite_0384-Mega.png → sprites\Mega
# Moved: Sprite_0384.png → sprites\national
# Moved: Sprite_0385.png → sprites\national
# Moved: Sprite_0386-Attack.png → sprites\Attack
# Moved: Sprite_0386-Defense.png → sprites\Defense
# Moved: Sprite_0386-Speed.png → sprites\Speed
# Moved: Sprite_0386.png → sprites\national
# Moved: Sprite_0387.png → sprites\national
# Moved: Sprite_0388.png → sprites\national
# Moved: Sprite_0389.png → sprites\national
# Moved: Sprite_0390.png → sprites\national
# Moved: Sprite_0391.png → sprites\national
# Moved: Sprite_0392.png → sprites\national
# Moved: Sprite_0393.png → sprites\national
# Moved: Sprite_0394.png → sprites\national
# Moved: Sprite_0395.png → sprites\national
# Moved: Sprite_0396.png → sprites\national
# Moved: Sprite_0397.png → sprites\national
# Moved: Sprite_0398.png → sprites\national
# Moved: Sprite_0399.png → sprites\national
# Moved: Sprite_0400.png → sprites\national
# Moved: Sprite_0401.png → sprites\national
# Moved: Sprite_0402.png → sprites\national
# Moved: Sprite_0403.png → sprites\national
# Moved: Sprite_0404.png → sprites\national
# Moved: Sprite_0405.png → sprites\national
# Moved: Sprite_0406.png → sprites\national
# Moved: Sprite_0407.png → sprites\national
# Moved: Sprite_0408.png → sprites\national
# Moved: Sprite_0409.png → sprites\national
# Moved: Sprite_0410.png → sprites\national
# Moved: Sprite_0411.png → sprites\national
# Moved: Sprite_0412-Sandy.png → sprites\Sandy
# Moved: Sprite_0412-Trash.png → sprites\Trash
# Moved: Sprite_0412.png → sprites\national
# Moved: Sprite_0413-Sandy.png → sprites\Sandy
# Moved: Sprite_0413-Trash.png → sprites\Trash
# Moved: Sprite_0413.png → sprites\national
# Moved: Sprite_0414.png → sprites\national
# Moved: Sprite_0415.png → sprites\national
# Moved: Sprite_0416.png → sprites\national
# Moved: Sprite_0417.png → sprites\national
# Moved: Sprite_0418.png → sprites\national
# Moved: Sprite_0419.png → sprites\national
# Moved: Sprite_0420.png → sprites\national
# Moved: Sprite_0421-Sunshine.png → sprites\Sunshine
# Moved: Sprite_0421.png → sprites\national
# Moved: Sprite_0422-East.png → sprites\East
# Moved: Sprite_0422.png → sprites\national
# Moved: Sprite_0423-East.png → sprites\East
# Moved: Sprite_0423.png → sprites\national
# Moved: Sprite_0424.png → sprites\national
# Moved: Sprite_0425.png → sprites\national
# Moved: Sprite_0426.png → sprites\national
# Moved: Sprite_0427.png → sprites\national
# Moved: Sprite_0428-Mega.png → sprites\Mega
# Moved: Sprite_0428.png → sprites\national
# Moved: Sprite_0429.png → sprites\national
# Moved: Sprite_0430.png → sprites\national
# Moved: Sprite_0431.png → sprites\national
# Moved: Sprite_0432.png → sprites\national
# Moved: Sprite_0433.png → sprites\national
# Moved: Sprite_0434.png → sprites\national
# Moved: Sprite_0435.png → sprites\national
# Moved: Sprite_0436.png → sprites\national
# Moved: Sprite_0437.png → sprites\national
# Moved: Sprite_0438.png → sprites\national
# Moved: Sprite_0439.png → sprites\national
# Moved: Sprite_0440.png → sprites\national
# Moved: Sprite_0441.png → sprites\national
# Moved: Sprite_0442.png → sprites\national
# Moved: Sprite_0443.png → sprites\national
# Moved: Sprite_0444.png → sprites\national
# Moved: Sprite_0445-Mega.png → sprites\Mega
# Moved: Sprite_0445.png → sprites\national
# Moved: Sprite_0446.png → sprites\national
# Moved: Sprite_0447.png → sprites\national
# Moved: Sprite_0448-Mega.png → sprites\Mega
# Moved: Sprite_0448.png → sprites\national
# Moved: Sprite_0449.png → sprites\national
# Moved: Sprite_0450.png → sprites\national
# Moved: Sprite_0451.png → sprites\national
# Moved: Sprite_0452.png → sprites\national
# Moved: Sprite_0453.png → sprites\national
# Moved: Sprite_0454.png → sprites\national
# Moved: Sprite_0455.png → sprites\national
# Moved: Sprite_0456.png → sprites\national
# Moved: Sprite_0457.png → sprites\national
# Moved: Sprite_0458.png → sprites\national
# Moved: Sprite_0459.png → sprites\national
# Moved: Sprite_0460-Mega.png → sprites\Mega
# Moved: Sprite_0460.png → sprites\national
# Moved: Sprite_0461.png → sprites\national
# Moved: Sprite_0462.png → sprites\national
# Moved: Sprite_0463.png → sprites\national
# Moved: Sprite_0464.png → sprites\national
# Moved: Sprite_0465.png → sprites\national
# Moved: Sprite_0466.png → sprites\national
# Moved: Sprite_0467.png → sprites\national
# Moved: Sprite_0468.png → sprites\national
# Moved: Sprite_0469.png → sprites\national
# Moved: Sprite_0470.png → sprites\national
# Moved: Sprite_0471.png → sprites\national
# Moved: Sprite_0472.png → sprites\national
# Moved: Sprite_0473.png → sprites\national
# Moved: Sprite_0474.png → sprites\national
# Moved: Sprite_0475-Mega.png → sprites\Mega
# Moved: Sprite_0475.png → sprites\national
# Moved: Sprite_0476.png → sprites\national
# Moved: Sprite_0477.png → sprites\national
# Moved: Sprite_0478.png → sprites\national
# Moved: Sprite_0479-Fan.png → sprites\Fan
# Moved: Sprite_0479-Frost.png → sprites\Frost
# Moved: Sprite_0479-Heat.png → sprites\Heat
# Moved: Sprite_0479-Mow.png → sprites\Mow
# Moved: Sprite_0479-Wash.png → sprites\Wash
# Moved: Sprite_0479.png → sprites\national
# Moved: Sprite_0480.png → sprites\national
# Moved: Sprite_0481.png → sprites\national
# Moved: Sprite_0482.png → sprites\national
# Moved: Sprite_0483-Origin.png → sprites\Origin
# Moved: Sprite_0483.png → sprites\national
# Moved: Sprite_0484-Origin.png → sprites\Origin
# Moved: Sprite_0484.png → sprites\national
# Moved: Sprite_0485.png → sprites\national
# Moved: Sprite_0486.png → sprites\national
# Moved: Sprite_0487-Origin.png → sprites\Origin
# Moved: Sprite_0487.png → sprites\national
# Moved: Sprite_0488.png → sprites\national
# Moved: Sprite_0489.png → sprites\national
# Moved: Sprite_0490.png → sprites\national
# Moved: Sprite_0491.png → sprites\national
# Moved: Sprite_0492-Sky.png → sprites\Sky
# Moved: Sprite_0492.png → sprites\national
# Moved: Sprite_0493-Bug.png → sprites\Bug
# Moved: Sprite_0493-Dark.png → sprites\Dark
# Moved: Sprite_0493-Dragon.png → sprites\Dragon
# Moved: Sprite_0493-Electric.png → sprites\Electric
# Moved: Sprite_0493-Fairy.png → sprites\Fairy
# Moved: Sprite_0493-Fighting.png → sprites\Fighting
# Moved: Sprite_0493-Fire.png → sprites\Fire
# Moved: Sprite_0493-Flying.png → sprites\Flying
# Moved: Sprite_0493-Ghost.png → sprites\Ghost
# Moved: Sprite_0493-Grass.png → sprites\Grass
# Moved: Sprite_0493-Ground.png → sprites\Ground
# Moved: Sprite_0493-Ice.png → sprites\Ice
# Moved: Sprite_0493-Poison.png → sprites\Poison
# Moved: Sprite_0493-Psychic.png → sprites\Psychic
# Moved: Sprite_0493-Rock.png → sprites\Rock
# Moved: Sprite_0493-Steel.png → sprites\Steel
# Moved: Sprite_0493-Water.png → sprites\Water
# Moved: Sprite_0493.png → sprites\national
# Moved: Sprite_0494.png → sprites\national
# Moved: Sprite_0495.png → sprites\national
# Moved: Sprite_0496.png → sprites\national
# Moved: Sprite_0497.png → sprites\national
# Moved: Sprite_0498.png → sprites\national
# Moved: Sprite_0499.png → sprites\national
# Moved: Sprite_0500.png → sprites\national
# Moved: Sprite_0501.png → sprites\national
# Moved: Sprite_0502.png → sprites\national
# Moved: Sprite_0503-Hisui.png → sprites\Hisui
# Moved: Sprite_0503.png → sprites\national
# Moved: Sprite_0504.png → sprites\national
# Moved: Sprite_0505.png → sprites\national
# Moved: Sprite_0506.png → sprites\national
# Moved: Sprite_0507.png → sprites\national
# Moved: Sprite_0508.png → sprites\national
# Moved: Sprite_0509.png → sprites\national
# Moved: Sprite_0510.png → sprites\national
# Moved: Sprite_0511.png → sprites\national
# Moved: Sprite_0512.png → sprites\national
# Moved: Sprite_0513.png → sprites\national
# Moved: Sprite_0514.png → sprites\national
# Moved: Sprite_0515.png → sprites\national
# Moved: Sprite_0516.png → sprites\national
# Moved: Sprite_0517.png → sprites\national
# Moved: Sprite_0518.png → sprites\national
# Moved: Sprite_0519.png → sprites\national
# Moved: Sprite_0520.png → sprites\national
# Moved: Sprite_0521-Female.png → sprites\Female
# Moved: Sprite_0521.png → sprites\national
# Moved: Sprite_0522.png → sprites\national
# Moved: Sprite_0523.png → sprites\national
# Moved: Sprite_0524.png → sprites\national
# Moved: Sprite_0525.png → sprites\national
# Moved: Sprite_0526.png → sprites\national
# Moved: Sprite_0527.png → sprites\national
# Moved: Sprite_0528.png → sprites\national
# Moved: Sprite_0529.png → sprites\national
# Moved: Sprite_0530.png → sprites\national
# Moved: Sprite_0531-Mega.png → sprites\Mega
# Moved: Sprite_0531.png → sprites\national
# Moved: Sprite_0532.png → sprites\national
# Moved: Sprite_0533.png → sprites\national
# Moved: Sprite_0534.png → sprites\national
# Moved: Sprite_0535.png → sprites\national
# Moved: Sprite_0536.png → sprites\national
# Moved: Sprite_0537.png → sprites\national
# Moved: Sprite_0538.png → sprites\national
# Moved: Sprite_0539.png → sprites\national
# Moved: Sprite_0540.png → sprites\national
# Moved: Sprite_0541.png → sprites\national
# Moved: Sprite_0542.png → sprites\national
# Moved: Sprite_0543.png → sprites\national
# Moved: Sprite_0544.png → sprites\national
# Moved: Sprite_0545.png → sprites\national
# Moved: Sprite_0546.png → sprites\national
# Moved: Sprite_0547.png → sprites\national
# Moved: Sprite_0548.png → sprites\national
# Moved: Sprite_0549-Hisui.png → sprites\Hisui
# Moved: Sprite_0549.png → sprites\national
# Moved: Sprite_0550-Blue.png → sprites\Blue
# Moved: Sprite_0550-White.png → sprites\White
# Moved: Sprite_0550.png → sprites\national
# Moved: Sprite_0551.png → sprites\national
# Moved: Sprite_0552.png → sprites\national
# Moved: Sprite_0553.png → sprites\national
# Moved: Sprite_0554-Galar.png → sprites\Galar
# Moved: Sprite_0554.png → sprites\national
# Moved: Sprite_0555-Galar.png → sprites\Galar
# Moved: Sprite_0555-Zen.png → sprites\Zen
# Moved: Sprite_0555-Zen_Galar.png → sprites\Zen_Galar
# Moved: Sprite_0555.png → sprites\national
# Moved: Sprite_0556.png → sprites\national
# Moved: Sprite_0557.png → sprites\national
# Moved: Sprite_0558.png → sprites\national
# Moved: Sprite_0559.png → sprites\national
# Moved: Sprite_0560.png → sprites\national
# Moved: Sprite_0561.png → sprites\national
# Moved: Sprite_0562-Galar.png → sprites\Galar
# Moved: Sprite_0562.png → sprites\national
# Moved: Sprite_0563.png → sprites\national
# Moved: Sprite_0564.png → sprites\national
# Moved: Sprite_0565.png → sprites\national
# Moved: Sprite_0566.png → sprites\national
# Moved: Sprite_0567.png → sprites\national
# Moved: Sprite_0568.png → sprites\national
# Moved: Sprite_0569.png → sprites\national
# Moved: Sprite_0570-Hisui.png → sprites\Hisui
# Moved: Sprite_0570.png → sprites\national
# Moved: Sprite_0571-Hisui.png → sprites\Hisui
# Moved: Sprite_0571.png → sprites\national
# Moved: Sprite_0572.png → sprites\national
# Moved: Sprite_0573.png → sprites\national
# Moved: Sprite_0574.png → sprites\national
# Moved: Sprite_0575.png → sprites\national
# Moved: Sprite_0576.png → sprites\national
# Moved: Sprite_0577.png → sprites\national
# Moved: Sprite_0578.png → sprites\national
# Moved: Sprite_0579.png → sprites\national
# Moved: Sprite_0580.png → sprites\national
# Moved: Sprite_0581.png → sprites\national
# Moved: Sprite_0582.png → sprites\national
# Moved: Sprite_0583.png → sprites\national
# Moved: Sprite_0584.png → sprites\national
# Moved: Sprite_0585-Autumn.png → sprites\Autumn
# Moved: Sprite_0585-Summer.png → sprites\Summer
# Moved: Sprite_0585-Winter.png → sprites\Winter
# Moved: Sprite_0585.png → sprites\national
# Moved: Sprite_0586-Autumn.png → sprites\Autumn
# Moved: Sprite_0586-Summer.png → sprites\Summer
# Moved: Sprite_0586-Winter.png → sprites\Winter
# Moved: Sprite_0586.png → sprites\national
# Moved: Sprite_0587.png → sprites\national
# Moved: Sprite_0588.png → sprites\national
# Moved: Sprite_0589.png → sprites\national
# Moved: Sprite_0590.png → sprites\national
# Moved: Sprite_0591.png → sprites\national
# Moved: Sprite_0592-Female.png → sprites\Female
# Moved: Sprite_0592.png → sprites\national
# Moved: Sprite_0593-Female.png → sprites\Female
# Moved: Sprite_0593.png → sprites\national
# Moved: Sprite_0594.png → sprites\national
# Moved: Sprite_0595.png → sprites\national
# Moved: Sprite_0596.png → sprites\national
# Moved: Sprite_0597.png → sprites\national
# Moved: Sprite_0598.png → sprites\national
# Moved: Sprite_0599.png → sprites\national
# Moved: Sprite_0600.png → sprites\national
# Moved: Sprite_0601.png → sprites\national
# Moved: Sprite_0602.png → sprites\national
# Moved: Sprite_0603.png → sprites\national
# Moved: Sprite_0604.png → sprites\national
# Moved: Sprite_0605.png → sprites\national
# Moved: Sprite_0606.png → sprites\national
# Moved: Sprite_0607.png → sprites\national
# Moved: Sprite_0608.png → sprites\national
# Moved: Sprite_0609.png → sprites\national
# Moved: Sprite_0610.png → sprites\national
# Moved: Sprite_0611.png → sprites\national
# Moved: Sprite_0612.png → sprites\national
# Moved: Sprite_0613.png → sprites\national
# Moved: Sprite_0614.png → sprites\national
# Moved: Sprite_0615.png → sprites\national
# Moved: Sprite_0616.png → sprites\national
# Moved: Sprite_0617.png → sprites\national
# Moved: Sprite_0618-Galar.png → sprites\Galar
# Moved: Sprite_0618.png → sprites\national
# Moved: Sprite_0619.png → sprites\national
# Moved: Sprite_0620.png → sprites\national
# Moved: Sprite_0621.png → sprites\national
# Moved: Sprite_0622.png → sprites\national
# Moved: Sprite_0623.png → sprites\national
# Moved: Sprite_0624.png → sprites\national
# Moved: Sprite_0625.png → sprites\national
# Moved: Sprite_0626.png → sprites\national
# Moved: Sprite_0627.png → sprites\national
# Moved: Sprite_0628-Hisui.png → sprites\Hisui
# Moved: Sprite_0628.png → sprites\national
# Moved: Sprite_0629.png → sprites\national
# Moved: Sprite_0630.png → sprites\national
# Moved: Sprite_0631.png → sprites\national
# Moved: Sprite_0632.png → sprites\national
# Moved: Sprite_0633.png → sprites\national
# Moved: Sprite_0634.png → sprites\national
# Moved: Sprite_0635.png → sprites\national
# Moved: Sprite_0636.png → sprites\national
# Moved: Sprite_0637.png → sprites\national
# Moved: Sprite_0638.png → sprites\national
# Moved: Sprite_0639.png → sprites\national
# Moved: Sprite_0640.png → sprites\national
# Moved: Sprite_0641-Therian.png → sprites\Therian
# Moved: Sprite_0641.png → sprites\national
# Moved: Sprite_0642-Therian.png → sprites\Therian
# Moved: Sprite_0642.png → sprites\national
# Moved: Sprite_0643.png → sprites\national
# Moved: Sprite_0644.png → sprites\national
# Moved: Sprite_0645-Therian.png → sprites\Therian
# Moved: Sprite_0645.png → sprites\national
# Moved: Sprite_0646-Black.png → sprites\Black
# Moved: Sprite_0646-White.png → sprites\White
# Moved: Sprite_0646.png → sprites\national
# Moved: Sprite_0647-Resolute.png → sprites\Resolute
# Moved: Sprite_0647.png → sprites\national
# Moved: Sprite_0648-Pirouette.png → sprites\Pirouette
# Moved: Sprite_0648.png → sprites\national
# Moved: Sprite_0649-Burn.png → sprites\Burn
# Moved: Sprite_0649-Chill.png → sprites\Chill
# Moved: Sprite_0649-Douse.png → sprites\Douse
# Moved: Sprite_0649-Shock.png → sprites\Shock
# Moved: Sprite_0649.png → sprites\national
# Moved: Sprite_0650.png → sprites\national
# Moved: Sprite_0651.png → sprites\national
# Moved: Sprite_0652.png → sprites\national
# Moved: Sprite_0653.png → sprites\national
# Moved: Sprite_0654.png → sprites\national
# Moved: Sprite_0655.png → sprites\national
# Moved: Sprite_0656.png → sprites\national
# Moved: Sprite_0657.png → sprites\national
# Moved: Sprite_0658-Ash.png → sprites\Ash
# Moved: Sprite_0658.png → sprites\national
# Moved: Sprite_0659.png → sprites\national
# Moved: Sprite_0660.png → sprites\national
# Moved: Sprite_0661.png → sprites\national
# Moved: Sprite_0662.png → sprites\national
# Moved: Sprite_0663.png → sprites\national
# Moved: Sprite_0664.png → sprites\national
# Moved: Sprite_0665.png → sprites\national
# Moved: Sprite_0666-Archipelago.png → sprites\Archipelago
# Moved: Sprite_0666-Continental.png → sprites\Continental
# Moved: Sprite_0666-Elegant.png → sprites\Elegant
# Moved: Sprite_0666-Fancy.png → sprites\Fancy
# Moved: Sprite_0666-Garden.png → sprites\Garden
# Moved: Sprite_0666-High_Plains.png → sprites\High_Plains
# Moved: Sprite_0666-Icy_Snow.png → sprites\Icy_Snow
# Moved: Sprite_0666-Jungle.png → sprites\Jungle
# Moved: Sprite_0666-Marine.png → sprites\Marine
# Moved: Sprite_0666-Modern.png → sprites\Modern
# Moved: Sprite_0666-Monsoon.png → sprites\Monsoon
# Moved: Sprite_0666-Ocean.png → sprites\Ocean
# Moved: Sprite_0666-Poké_Ball.png → sprites\Poké_Ball
# Moved: Sprite_0666-Polar.png → sprites\Polar
# Moved: Sprite_0666-River.png → sprites\River
# Moved: Sprite_0666-Sandstorm.png → sprites\Sandstorm
# Moved: Sprite_0666-Savanna.png → sprites\Savanna
# Moved: Sprite_0666-Sun.png → sprites\Sun
# Moved: Sprite_0666-Tundra.png → sprites\Tundra
# Moved: Sprite_0666.png → sprites\national
# Moved: Sprite_0667.png → sprites\national
# Moved: Sprite_0668-Female.png → sprites\Female
# Moved: Sprite_0668.png → sprites\national
# Moved: Sprite_0669-Blue.png → sprites\Blue
# Moved: Sprite_0669-Orange.png → sprites\Orange
# Moved: Sprite_0669-White.png → sprites\White
# Moved: Sprite_0669-Yellow.png → sprites\Yellow
# Moved: Sprite_0669.png → sprites\national
# Moved: Sprite_0670-Blue.png → sprites\Blue
# Moved: Sprite_0670-Eternal.png → sprites\Eternal
# Moved: Sprite_0670-Orange.png → sprites\Orange
# Moved: Sprite_0670-White.png → sprites\White
# Moved: Sprite_0670-Yellow.png → sprites\Yellow
# Moved: Sprite_0670.png → sprites\national
# Moved: Sprite_0671-Blue.png → sprites\Blue
# Moved: Sprite_0671-Orange.png → sprites\Orange
# Moved: Sprite_0671-White.png → sprites\White
# Moved: Sprite_0671-Yellow.png → sprites\Yellow
# Moved: Sprite_0671.png → sprites\national
# Moved: Sprite_0672.png → sprites\national
# Moved: Sprite_0673.png → sprites\national
# Moved: Sprite_0674.png → sprites\national
# Moved: Sprite_0675.png → sprites\national
# Moved: Sprite_0676-Dandy.png → sprites\Dandy
# Moved: Sprite_0676-Debutante.png → sprites\Debutante
# Moved: Sprite_0676-Diamond.png → sprites\Diamond
# Moved: Sprite_0676-Heart.png → sprites\Heart
# Moved: Sprite_0676-Kabuki.png → sprites\Kabuki
# Moved: Sprite_0676-La_Reine.png → sprites\La_Reine
# Moved: Sprite_0676-Matron.png → sprites\Matron
# Moved: Sprite_0676-Pharaoh.png → sprites\Pharaoh
# Moved: Sprite_0676-Star.png → sprites\Star
# Moved: Sprite_0676.png → sprites\national
# Moved: Sprite_0677.png → sprites\national
# Moved: Sprite_0678-Female.png → sprites\Female
# Moved: Sprite_0678.png → sprites\national
# Moved: Sprite_0679.png → sprites\national
# Moved: Sprite_0680.png → sprites\national
# Moved: Sprite_0681-Blade.png → sprites\Blade
# Moved: Sprite_0681.png → sprites\national
# Moved: Sprite_0682.png → sprites\national
# Moved: Sprite_0683.png → sprites\national
# Moved: Sprite_0684.png → sprites\national
# Moved: Sprite_0685.png → sprites\national
# Moved: Sprite_0686.png → sprites\national
# Moved: Sprite_0687.png → sprites\national
# Moved: Sprite_0688.png → sprites\national
# Moved: Sprite_0689.png → sprites\national
# Moved: Sprite_0690.png → sprites\national
# Moved: Sprite_0691.png → sprites\national
# Moved: Sprite_0692.png → sprites\national
# Moved: Sprite_0693.png → sprites\national
# Moved: Sprite_0694.png → sprites\national
# Moved: Sprite_0695.png → sprites\national
# Moved: Sprite_0696.png → sprites\national
# Moved: Sprite_0697.png → sprites\national
# Moved: Sprite_0698.png → sprites\national
# Moved: Sprite_0699.png → sprites\national
# Moved: Sprite_0700.png → sprites\national
# Moved: Sprite_0701.png → sprites\national
# Moved: Sprite_0702.png → sprites\national
# Moved: Sprite_0703.png → sprites\national
# Moved: Sprite_0704.png → sprites\national
# Moved: Sprite_0705-Hisui.png → sprites\Hisui
# Moved: Sprite_0705.png → sprites\national
# Moved: Sprite_0706-Hisui.png → sprites\Hisui
# Moved: Sprite_0706.png → sprites\national
# Moved: Sprite_0707.png → sprites\national
# Moved: Sprite_0708.png → sprites\national
# Moved: Sprite_0709.png → sprites\national
# Moved: Sprite_0710-Large.png → sprites\Large
# Moved: Sprite_0710-Small.png → sprites\Small
# Moved: Sprite_0710-Super.png → sprites\Super
# Moved: Sprite_0710.png → sprites\national
# Moved: Sprite_0711-Large.png → sprites\Large
# Moved: Sprite_0711-Small.png → sprites\Small
# Moved: Sprite_0711-Super.png → sprites\Super
# Moved: Sprite_0711.png → sprites\national
# Moved: Sprite_0712.png → sprites\national
# Moved: Sprite_0713-Hisui.png → sprites\Hisui
# Moved: Sprite_0713.png → sprites\national
# Moved: Sprite_0714.png → sprites\national
# Moved: Sprite_0715.png → sprites\national
# Moved: Sprite_0716-Neutral.png → sprites\Neutral
# Moved: Sprite_0716.png → sprites\national
# Moved: Sprite_0717.png → sprites\national
# Moved: Sprite_0718-10_Percent.png → sprites\10_Percent
# Moved: Sprite_0718-Complete.png → sprites\Complete
# Moved: Sprite_0718.png → sprites\national
# Moved: Sprite_0719-Mega.png → sprites\Mega
# Moved: Sprite_0719.png → sprites\national
# Moved: Sprite_0720-Unbound.png → sprites\Unbound
# Moved: Sprite_0720.png → sprites\national
# Moved: Sprite_0721.png → sprites\national
# Moved: Sprite_0722.png → sprites\national
# Moved: Sprite_0723.png → sprites\national
# Moved: Sprite_0724-Hisui.png → sprites\Hisui
# Moved: Sprite_0724.png → sprites\national
# Moved: Sprite_0725.png → sprites\national
# Moved: Sprite_0726.png → sprites\national
# Moved: Sprite_0727.png → sprites\national
# Moved: Sprite_0728.png → sprites\national
# Moved: Sprite_0729.png → sprites\national
# Moved: Sprite_0730.png → sprites\national
# Moved: Sprite_0731.png → sprites\national
# Moved: Sprite_0732.png → sprites\national
# Moved: Sprite_0733.png → sprites\national
# Moved: Sprite_0734.png → sprites\national
# Moved: Sprite_0735.png → sprites\national
# Moved: Sprite_0736.png → sprites\national
# Moved: Sprite_0737.png → sprites\national
# Moved: Sprite_0738.png → sprites\national
# Moved: Sprite_0739.png → sprites\national
# Moved: Sprite_0740.png → sprites\national
# Moved: Sprite_0741-Sensu.png → sprites\Sensu
# Moved: Sprite_0741.png → sprites\national
# Moved: Sprite_0742.png → sprites\national
# Moved: Sprite_0743.png → sprites\national
# Moved: Sprite_0744.png → sprites\national
# Moved: Sprite_0745-Dusk.png → sprites\Dusk
# Moved: Sprite_0745-Midnight.png → sprites\Midnight
# Moved: Sprite_0745.png → sprites\national
# Moved: Sprite_0746-School.png → sprites\School
# Moved: Sprite_0746.png → sprites\national
# Moved: Sprite_0747.png → sprites\national
# Moved: Sprite_0748.png → sprites\national
# Moved: Sprite_0749.png → sprites\national
# Moved: Sprite_0750.png → sprites\national
# Moved: Sprite_0751.png → sprites\national
# Moved: Sprite_0752.png → sprites\national
# Moved: Sprite_0753.png → sprites\national
# Moved: Sprite_0754.png → sprites\national
# Moved: Sprite_0755.png → sprites\national
# Moved: Sprite_0756.png → sprites\national
# Moved: Sprite_0757.png → sprites\national
# Moved: Sprite_0758.png → sprites\national
# Moved: Sprite_0759.png → sprites\national
# Moved: Sprite_0760.png → sprites\national
# Moved: Sprite_0761.png → sprites\national
# Moved: Sprite_0762.png → sprites\national
# Moved: Sprite_0763.png → sprites\national
# Moved: Sprite_0764.png → sprites\national
# Moved: Sprite_0765.png → sprites\national
# Moved: Sprite_0766.png → sprites\national
# Moved: Sprite_0767.png → sprites\national
# Moved: Sprite_0768.png → sprites\national
# Moved: Sprite_0769.png → sprites\national
# Moved: Sprite_0770.png → sprites\national
# Moved: Sprite_0771.png → sprites\national
# Moved: Sprite_0772.png → sprites\national
# Moved: Sprite_0773.png → sprites\national
# Moved: Sprite_0774-Blue.png → sprites\Blue
# Moved: Sprite_0774-Green.png → sprites\Green
# Moved: Sprite_0774-Indigo.png → sprites\Indigo
# Moved: Sprite_0774-Orange.png → sprites\Orange
# Moved: Sprite_0774-Red.png → sprites\Red
# Moved: Sprite_0774-Violet.png → sprites\Violet
# Moved: Sprite_0774-Yellow.png → sprites\Yellow
# Moved: Sprite_0774.png → sprites\national
# Moved: Sprite_0775.png → sprites\national
# Moved: Sprite_0776.png → sprites\national
# Moved: Sprite_0777.png → sprites\national
# Moved: Sprite_0778.png → sprites\national
# Moved: Sprite_0779.png → sprites\national
# Moved: Sprite_0780.png → sprites\national
# Moved: Sprite_0781.png → sprites\national
# Moved: Sprite_0782.png → sprites\national
# Moved: Sprite_0783.png → sprites\national
# Moved: Sprite_0784.png → sprites\national
# Moved: Sprite_0785.png → sprites\national
# Moved: Sprite_0786.png → sprites\national
# Moved: Sprite_0787.png → sprites\national
# Moved: Sprite_0788.png → sprites\national
# Moved: Sprite_0789.png → sprites\national
# Moved: Sprite_0790.png → sprites\national
# Moved: Sprite_0791.png → sprites\national
# Moved: Sprite_0792.png → sprites\national
# Moved: Sprite_0793.png → sprites\national
# Moved: Sprite_0794.png → sprites\national
# Moved: Sprite_0795.png → sprites\national
# Moved: Sprite_0796.png → sprites\national
# Moved: Sprite_0797.png → sprites\national
# Moved: Sprite_0798.png → sprites\national
# Moved: Sprite_0799.png → sprites\national
# Moved: Sprite_0800-Dawn_Wings.png → sprites\Dawn_Wings
# Moved: Sprite_0800-Dusk_Mane.png → sprites\Dusk_Mane
# Moved: Sprite_0800-Ultra.png → sprites\Ultra
# Moved: Sprite_0800.png → sprites\national
# Moved: Sprite_0801-Original_Color.png → sprites\Original_Color
# Moved: Sprite_0801.png → sprites\national
# Moved: Sprite_0802.png → sprites\national
# Moved: Sprite_0803.png → sprites\national
# Moved: Sprite_0804.png → sprites\national
# Moved: Sprite_0805.png → sprites\national
# Moved: Sprite_0806.png → sprites\national
# Moved: Sprite_0807.png → sprites\national
# Moved: Sprite_0808.png → sprites\national
# Moved: Sprite_0809.png → sprites\national
# Moved: Sprite_0810.png → sprites\national
# Moved: Sprite_0811.png → sprites\national
# Moved: Sprite_0812.png → sprites\national
# Moved: Sprite_0813.png → sprites\national
# Moved: Sprite_0814.png → sprites\national
# Moved: Sprite_0815.png → sprites\national
# Moved: Sprite_0816.png → sprites\national
# Moved: Sprite_0817.png → sprites\national
# Moved: Sprite_0818.png → sprites\national
# Moved: Sprite_0819.png → sprites\national
# Moved: Sprite_0820.png → sprites\national
# Moved: Sprite_0821.png → sprites\national
# Moved: Sprite_0822.png → sprites\national
# Moved: Sprite_0823.png → sprites\national
# Moved: Sprite_0824.png → sprites\national
# Moved: Sprite_0825.png → sprites\national
# Moved: Sprite_0826.png → sprites\national
# Moved: Sprite_0827.png → sprites\national
# Moved: Sprite_0828.png → sprites\national
# Moved: Sprite_0829.png → sprites\national
# Moved: Sprite_0830.png → sprites\national
# Moved: Sprite_0831.png → sprites\national
# Moved: Sprite_0832.png → sprites\national
# Moved: Sprite_0833.png → sprites\national
# Moved: Sprite_0834.png → sprites\national
# Moved: Sprite_0835.png → sprites\national
# Moved: Sprite_0836.png → sprites\national
# Moved: Sprite_0837.png → sprites\national
# Moved: Sprite_0838.png → sprites\national
# Moved: Sprite_0839.png → sprites\national
# Moved: Sprite_0840.png → sprites\national
# Moved: Sprite_0841.png → sprites\national
# Moved: Sprite_0842.png → sprites\national
# Moved: Sprite_0843.png → sprites\national
# Moved: Sprite_0844.png → sprites\national
# Moved: Sprite_0845-Gorging.png → sprites\Gorging
# Moved: Sprite_0845-Gulping.png → sprites\Gulping
# Moved: Sprite_0845.png → sprites\national
# Moved: Sprite_0846.png → sprites\national
# Moved: Sprite_0847.png → sprites\national
# Moved: Sprite_0848.png → sprites\national
# Moved: Sprite_0849-Low_Key.png → sprites\Low_Key
# Moved: Sprite_0849.png → sprites\national
# Moved: Sprite_0850.png → sprites\national
# Moved: Sprite_0851.png → sprites\national
# Moved: Sprite_0852.png → sprites\national
# Moved: Sprite_0853.png → sprites\national
# Moved: Sprite_0854.png → sprites\national
# Moved: Sprite_0855.png → sprites\national
# Moved: Sprite_0856.png → sprites\national
# Moved: Sprite_0857.png → sprites\national
# Moved: Sprite_0858.png → sprites\national
# Moved: Sprite_0859.png → sprites\national
# Moved: Sprite_0860.png → sprites\national
# Moved: Sprite_0861.png → sprites\national
# Moved: Sprite_0862.png → sprites\national
# Moved: Sprite_0863.png → sprites\national
# Moved: Sprite_0864.png → sprites\national
# Moved: Sprite_0865.png → sprites\national
# Moved: Sprite_0866.png → sprites\national
# Moved: Sprite_0867.png → sprites\national
# Moved: Sprite_0868.png → sprites\national
# Moved: Sprite_0869-Caramel.png → sprites\Caramel
# Moved: Sprite_0869-Lemon.png → sprites\Lemon
# Moved: Sprite_0869-Matcha.png → sprites\Matcha
# Moved: Sprite_0869-Mint.png → sprites\Mint
# Moved: Sprite_0869-Rainbow.png → sprites\Rainbow
# Moved: Sprite_0869-Ruby.png → sprites\Ruby
# Moved: Sprite_0869-Ruby_Swirl.png → sprites\Ruby_Swirl
# Moved: Sprite_0869-Salted.png → sprites\Salted
# Moved: Sprite_0869.png → sprites\national
# Moved: Sprite_0870.png → sprites\national
# Moved: Sprite_0871.png → sprites\national
# Moved: Sprite_0872.png → sprites\national
# Moved: Sprite_0873.png → sprites\national
# Moved: Sprite_0874.png → sprites\national
# Moved: Sprite_0875-Noice.png → sprites\Noice
# Moved: Sprite_0875.png → sprites\national
# Moved: Sprite_0876-Female.png → sprites\Female
# Moved: Sprite_0876.png → sprites\national
# Moved: Sprite_0877-Hangry.png → sprites\Hangry
# Moved: Sprite_0877.png → sprites\national
# Moved: Sprite_0878.png → sprites\national
# Moved: Sprite_0879.png → sprites\national
# Moved: Sprite_0880.png → sprites\national
# Moved: Sprite_0881.png → sprites\national
# Moved: Sprite_0882.png → sprites\national
# Moved: Sprite_0883.png → sprites\national
# Moved: Sprite_0884.png → sprites\national
# Moved: Sprite_0885.png → sprites\national
# Moved: Sprite_0886.png → sprites\national
# Moved: Sprite_0887.png → sprites\national
# Moved: Sprite_0888-Crowned.png → sprites\Crowned
# Moved: Sprite_0888.png → sprites\national
# Moved: Sprite_0889-Crowned.png → sprites\Crowned
# Moved: Sprite_0889.png → sprites\national
# Moved: Sprite_0890.png → sprites\national
# Moved: Sprite_0891.png → sprites\national
# Moved: Sprite_0892.png → sprites\national
# Moved: Sprite_0893-Dada.png → sprites\Dada
# Moved: Sprite_0893.png → sprites\national
# Moved: Sprite_0894.png → sprites\national
# Moved: Sprite_0895.png → sprites\national
# Moved: Sprite_0896.png → sprites\national
# Moved: Sprite_0897.png → sprites\national
# Moved: Sprite_0898-Ice_Rider.png → sprites\Ice_Rider
# Moved: Sprite_0898-Shadow_Rider.png → sprites\Shadow_Rider
# Moved: Sprite_0898.png → sprites\national
# Moved: Sprite_0899.png → sprites\national
# Moved: Sprite_0900.png → sprites\national
# Moved: Sprite_0901-Bloodmoon.png → sprites\Bloodmoon
# Moved: Sprite_0901.png → sprites\national
# Moved: Sprite_0902-Female.png → sprites\Female
# Moved: Sprite_0902.png → sprites\national
# Moved: Sprite_0903.png → sprites\national
# Moved: Sprite_0904.png → sprites\national
# Moved: Sprite_0905-Therian.png → sprites\Therian
# Moved: Sprite_0905.png → sprites\national
# Moved: Sprite_0906.png → sprites\national
# Moved: Sprite_0907.png → sprites\national
# Moved: Sprite_0908.png → sprites\national
# Moved: Sprite_0909.png → sprites\national
# Moved: Sprite_0910.png → sprites\national
# Moved: Sprite_0911.png → sprites\national
# Moved: Sprite_0912.png → sprites\national
# Moved: Sprite_0913.png → sprites\national
# Moved: Sprite_0914.png → sprites\national
# Moved: Sprite_0915.png → sprites\national
# Moved: Sprite_0916-Female.png → sprites\Female
# Moved: Sprite_0916.png → sprites\national
# Moved: Sprite_0917.png → sprites\national
# Moved: Sprite_0918.png → sprites\national
# Moved: Sprite_0919.png → sprites\national
# Moved: Sprite_0920.png → sprites\national
# Moved: Sprite_0921.png → sprites\national
# Moved: Sprite_0922.png → sprites\national
# Moved: Sprite_0923.png → sprites\national
# Moved: Sprite_0924.png → sprites\national
# Moved: Sprite_0925-Three.png → sprites\Three
# Moved: Sprite_0925.png → sprites\national
# Moved: Sprite_0926.png → sprites\national
# Moved: Sprite_0927.png → sprites\national
# Moved: Sprite_0928.png → sprites\national
# Moved: Sprite_0929.png → sprites\national
# Moved: Sprite_0930.png → sprites\national
# Moved: Sprite_0931-Blue.png → sprites\Blue
# Moved: Sprite_0931-White.png → sprites\White
# Moved: Sprite_0931-Yellow.png → sprites\Yellow
# Moved: Sprite_0931.png → sprites\national
# Moved: Sprite_0932.png → sprites\national
# Moved: Sprite_0933.png → sprites\national
# Moved: Sprite_0934.png → sprites\national
# Moved: Sprite_0935.png → sprites\national
# Moved: Sprite_0936.png → sprites\national
# Moved: Sprite_0937.png → sprites\national
# Moved: Sprite_0938.png → sprites\national
# Moved: Sprite_0939.png → sprites\national
# Moved: Sprite_0940.png → sprites\national
# Moved: Sprite_0941.png → sprites\national
# Moved: Sprite_0942.png → sprites\national
# Moved: Sprite_0943.png → sprites\national
# Moved: Sprite_0944.png → sprites\national
# Moved: Sprite_0945.png → sprites\national
# Moved: Sprite_0946.png → sprites\national
# Moved: Sprite_0947.png → sprites\national
# Moved: Sprite_0948.png → sprites\national
# Moved: Sprite_0949.png → sprites\national
# Moved: Sprite_0950.png → sprites\national
# Moved: Sprite_0951.png → sprites\national
# Moved: Sprite_0952.png → sprites\national
# Moved: Sprite_0953.png → sprites\national
# Moved: Sprite_0954.png → sprites\national
# Moved: Sprite_0955.png → sprites\national
# Moved: Sprite_0956.png → sprites\national
# Moved: Sprite_0957.png → sprites\national
# Moved: Sprite_0958.png → sprites\national
# Moved: Sprite_0959.png → sprites\national
# Moved: Sprite_0960.png → sprites\national
# Moved: Sprite_0961.png → sprites\national
# Moved: Sprite_0962.png → sprites\national
# Moved: Sprite_0963.png → sprites\national
# Moved: Sprite_0964-Hero.png → sprites\Hero
# Moved: Sprite_0964.png → sprites\national
# Moved: Sprite_0965.png → sprites\national
# Moved: Sprite_0966.png → sprites\national
# Moved: Sprite_0967.png → sprites\national
# Moved: Sprite_0968.png → sprites\national
# Moved: Sprite_0969.png → sprites\national
# Moved: Sprite_0970.png → sprites\national
# Moved: Sprite_0971.png → sprites\national
# Moved: Sprite_0972.png → sprites\national
# Moved: Sprite_0973.png → sprites\national
# Moved: Sprite_0974.png → sprites\national
# Moved: Sprite_0975.png → sprites\national
# Moved: Sprite_0976.png → sprites\national
# Moved: Sprite_0977.png → sprites\national
# Moved: Sprite_0978-Droopy.png → sprites\Droopy
# Moved: Sprite_0978-Stretchy.png → sprites\Stretchy
# Moved: Sprite_0978.png → sprites\national
# Moved: Sprite_0979.png → sprites\national
# Moved: Sprite_0980.png → sprites\national
# Moved: Sprite_0981.png → sprites\national
# Moved: Sprite_0982.png → sprites\national
# Moved: Sprite_0983.png → sprites\national
# Moved: Sprite_0984.png → sprites\national
# Moved: Sprite_0985.png → sprites\national
# Moved: Sprite_0986.png → sprites\national
# Moved: Sprite_0987.png → sprites\national
# Moved: Sprite_0988.png → sprites\national
# Moved: Sprite_0989.png → sprites\national
# Moved: Sprite_0990.png → sprites\national
# Moved: Sprite_0991.png → sprites\national
# Moved: Sprite_0992.png → sprites\national
# Moved: Sprite_0993.png → sprites\national
# Moved: Sprite_0994.png → sprites\national
# Moved: Sprite_0995.png → sprites\national
# Moved: Sprite_0996.png → sprites\national
# Moved: Sprite_0997.png → sprites\national
# Moved: Sprite_0998.png → sprites\national
# Moved: Sprite_0999-Roaming.png → sprites\Roaming
# Moved: Sprite_0999.png → sprites\national
# Moved: Sprite_1000.png → sprites\national
# Moved: Sprite_1001.png → sprites\national
# Moved: Sprite_1002.png → sprites\national
# Moved: Sprite_1003.png → sprites\national
# Moved: Sprite_1004.png → sprites\national
# Moved: Sprite_1005.png → sprites\national
# Moved: Sprite_1006.png → sprites\national
# Moved: Sprite_1007-Sprinting.png → sprites\Sprinting
# Moved: Sprite_1007.png → sprites\national
# Moved: Sprite_1008-Drive.png → sprites\Drive
# Moved: Sprite_1008.png → sprites\national
# Moved: Sprite_1009.png → sprites\national
# Moved: Sprite_1010.png → sprites\national
# Moved: Sprite_1011.png → sprites\national
# Moved: Sprite_1012.png → sprites\national
# Moved: Sprite_1013.png → sprites\national
# Moved: Sprite_1014.png → sprites\national
# Moved: Sprite_1015.png → sprites\national
# Moved: Sprite_1016.png → sprites\national
# Moved: Sprite_1017-Cornerstone_Mask.png → sprites\Cornerstone_Mask
# Moved: Sprite_1017-Hearthflame_Mask.png → sprites\Hearthflame_Mask
# Moved: Sprite_1017-Wellspring_Mask.png → sprites\Wellspring_Mask
# Moved: Sprite_1017.png → sprites\national
# Moved: Sprite_1018.png → sprites\national
# Moved: Sprite_1019.png → sprites\national
# Moved: Sprite_1020.png → sprites\national
# Moved: Sprite_1021.png → sprites\national
# Moved: Sprite_1022.png → sprites\national
# Moved: Sprite_1023.png → sprites\national
# Moved: Sprite_1024.png → sprites\national
# Moved: Sprite_1025.png → sprites\national

# %%
import os
import re
import requests
from bs4 import BeautifulSoup

base = 'https://archives.bulbagarden.net'
category_url = base + '/w/index.php?title=Category:Type_icons'

# Regular expressions to match the filenames we are interested in
pattern_sw = re.compile(r'^(\w+) icon SwSh\.png$')
pattern_la = re.compile(r'^(\w+) icon LA\.png$')

# Function to download images for each page
def download_icons(page_url):
    resp = requests.get(page_url)
    soup = BeautifulSoup(resp.text, 'html.parser')

    # Iterate over each image item and check if it matches the required pattern
    for img_item in soup.select('li a'):  # or whatever tag holds file links
        fname = img_item.text.strip()
        m_sw = pattern_sw.match(fname)
        m_la = pattern_la.match(fname)
        if not (m_sw or m_la):
            continue
        type_name = (m_sw or m_la).group(1)
        filepage_url = base + img_item['href']
        
        # Fetch file page
        fp = requests.get(filepage_url)
        fsoup = BeautifulSoup(fp.text, 'html.parser')
        
        # Locate the actual image URL (often via <a class="internal"> or <div class="fullMedia">)
        img = fsoup.find('a', class_='internal')
        img_url = img['href']
        
        # Determine folder and filename
        folder = 'Small_Sprites' if m_sw else 'Full_Icons'
        outname = f"{type_name}_Small_Icon.png" if m_sw else f"{type_name}_Full_Icon.png"
        
        # Create folder if it doesn't exist
        os.makedirs(folder, exist_ok=True)
        
        # Download and save image
        img_data = requests.get(img_url).content
        with open(os.path.join(folder, outname), 'wb') as f:
            f.write(img_data)
        print(f'Saved: {outname}')

# Start scraping from the first page
download_icons(category_url)

# Now check for the next page (pagination)
previous_page_url = category_url  # Initial page URL

while True:
    # Get the last file name on the current page
    soup = BeautifulSoup(requests.get(previous_page_url).text, 'html.parser')
    last_file_name = soup.find_all('li')[-1].find('a')['href'].split('filefrom=')[-1]

    # Construct URL for the next page using the last file name as the "filefrom" value
    next_page_url = f"{category_url}&filefrom={last_file_name}"

    # If the URL doesn't change, we've reached the last page
    if next_page_url == previous_page_url:
        print("No more pages to scrape.")
        break  # Break if there is no next page
    
    # Download images from the next page
    print(f"Scraping next page: {next_page_url}")
    download_icons(next_page_url)

    # Update previous_page_url for the next iteration
    previous_page_url = next_page_url
# Out:
# Saved: Bug_Full_Icon.png
# Saved: Bug_Small_Icon.png
# Saved: Dark_Full_Icon.png
# Saved: Dark_Small_Icon.png
# Saved: Dragon_Full_Icon.png
# Saved: Dragon_Small_Icon.png
# Saved: Electric_Full_Icon.png
# Saved: Electric_Small_Icon.png
# Saved: Fairy_Full_Icon.png
# Saved: Fairy_Small_Icon.png
# Saved: Fighting_Full_Icon.png
# Saved: Fighting_Small_Icon.png
# Saved: Fire_Full_Icon.png
# Saved: Fire_Small_Icon.png
# No more pages to scrape.
# C:\Users\tisor\AppData\Local\Temp\ipykernel_33184\330855872.py:61: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   filefrom_link = soup.find('a', text='next')  # Adjust this to the correct selector
